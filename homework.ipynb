# %% [markdown]
# # Домашнее задание № 1

# %% [markdown]
# ## 1. Задание на удаление тегов (2 балла)

# %% [markdown]
# Часто в данных, с которыми нам нужно работать помимо текста присутствует ещё какая-то лишняя информация: тэги, ссылки, код, разметка. Она, конечно, не всегда лишняя, но обычно от неё лучше избавиться.

# %% [markdown]
# Возьмем в качестве примера статью с Хабрахабра. Она скачана автоматически и в там остались некоторые тэги.

# %%
text = '''
Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — <a href="http://www.crazyegg.com" title="Сумасшедшие яйца">CrazyEgg</a>. Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо. Запоминается? Отлично!<br><br><img src="http://img172.imageshack.us/img172/8434/18274658kc4.png" alt="Сумасшедшее яйцо"><br><br><blockquote><h3>Что это такое?</h3><br>
Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.<br>
Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые).<br><br><img src="https://habrastorage.org/getpro/habr/post_images/7c7/298/33c/7c729833cd942cc493e68833e3e0f12d.jpg" alt="Тепловое отслеживание популярности"><br></blockquote><br><br><a name="habracut"></a><br><br><blockquote><h3>Для кого это?</h3><br>
Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад. Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную. Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/0b0/0a0/b16/0b00a0b16b1eda28e35f39487dcd2545.jpg" alt="Отслеживание ссылок"></blockquote><br><blockquote><img src="https://habrastorage.org/getpro/habr/post_images/0b5/433/892/0b54338921665ffb5a90930147296f5b.jpg" alt="Список по популярности"><br><br>
Да-да, сервис не бесплатен. Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса).</blockquote><br><blockquote><h3>Зачем это?</h3><br>
С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего. Больше не нужно спорить создателям — какой блок где расположить. В этом им поможет <a href="http://ttp://www.crazyegg.com" title="Сумасшедшие яйца">Сумасшедшее яйцо</a>.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/38c/af8/e75/38caf8e753782a01dc6419d3902edd57.jpg" alt="Добавление проекта"></blockquote><br><blockquote>Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации. Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/0dd/3fb/b34/0dd3fbb34709e77f3fbcd6523c7eac77.jpg" alt="еще полезности"></blockquote><br><blockquote><h3>Как это работает?</h3><br>
Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание. Насколько я понял — исполнительный скрипт работает на сервере <a href="http://www.crazyegg.com" title="Сумасшедшие яйца">CrazyEgg</a>, поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/a90/e4e/e67/a90e4ee6760978463e6306a2f5982e24.jpg" alt="управление популярностью"></blockquote><br><blockquote><h3>Сколько это стоит?</h3><br>
Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию. Расскажу подробнее о тарификации.</blockquote><br><blockquote>1. Бесплатная тестовая версия. Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте.<br><br>
2. Базовая версия. В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта. Стоит базовый комплект — 9 долларов в месяц. В этот комплект включены все дополнительные функции.<br><br>
3. Версия «Стандарт». В неё входит возможность отслеживания 25 000 посещений на 20 страницах. Вполне подходит для тестирования нового стартапа. Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора.<br><br>
4. Версия «Плюс». Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц. Очень хороший тариф для крупных сервисов. Стоит 49 долларов в месяц. Довольно большие деньги за сервис, но они обычно с лихвой окупаются.<br><br>
5. Версия «Про». Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах. Тариф подходит для монстров с большой посещаемостью и большим количеством страниц.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/f73/fb2/62d/f73fb262da4618a8dde67690cfd191ea.jpg" alt="Отслеживание статистики"></blockquote><br><blockquote><h3>Есть и аналоги</h3><br>
Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле.</blockquote><br><blockquote> 1. <a href="https://www.google.com/analytics/home/?hl=en" title="Шикарный сбор и анализ статистики">Google Analytics</a> — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков. Очень подробная и полезная вещь. Рекомендую, т.к. сам пользуюсь им для этого блога.<br><br>
2. <a href="http://www.mapsurface.com/" title="Сервис для отслеживания популярности блоков на сайте">MapSurface</a> — сам еще не использовал (т.к. предпочел CrazyEgg), но врядли будучи плохим сервис собрал бы множество положительных отзывов. К сожалению он сейчас находится в статусе закрытой беты.</blockquote><br><blockquote><h3>Вывод</h3><br>
Использовать можно, и нужно. Вот только тарифы довольно больно кусаются, но обычно эти деньги потом с лихвой отбиваются на повышении конвертации посетителей в деньги. Использовать сервис нужно для тестирования рекламных мест и удобства отдельных страниц, что помогает опять же повысить конвертацию. В общем и целом — <a href="http://ttp://www.crazyegg.com">полезная вещь</a> для каждого владельца сайтов, а для юзабилиста вообще практически обязательна. К счастью для людей, которые поиздержались деньгами в этом месяце — есть полезные аналоги.<br><br><img src="http://img241.imageshack.us/img241/2346/confettitnml5.jpg" alt="Интересная идея визуализации популярности - конфети"></blockquote><br><br>
Автор: <a href="http://www.birzool.com/" title="Я пишу о юзабилити веб интерфейсов">Ярослав Бирзул</a> (DezmASter).<br>
Источник: <a href="http://www.birzool.com/crazyegg/" title="Сумасшедшие яйца, первоисточник">Блог о юзабилити веб интерфейсов</a>.<br><br>
PS: Всех с прошедшим Новым годом! От всей души желаю вам всего самого-самого лучшего, чего вы желаете только в самых сокровенных мечтах. Удачно вам провести время.
'''

# %% [markdown]
# С помощью регулярных выражение очистите текст от тэгов (мета информацию внутри тэгов тоже удалите). В получившемся тексте точки не должны слипаться с началом следующего предложений, также не должно быть лишних пробелов.

# %%
import re

# %%
def remove_tags(text):
    #удаляем все тэги
    text = re.sub('<[^>]*>', '', text)
    #удаляем все символы новой строки
    text = re.sub('\n', '', text)
    #удаляем все слипания
    text = re.sub('(\.|\?|\!)([А-ЯA-Z]|\d)',r'\1 \2', text)
    text= re.sub('([а-яА-Я])(\w+)([А-Я])', r'\1\2 \3', text)
    return text

# %%
text = remove_tags(text)
text
# Out:
# 'Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg. Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо. Запоминается? Отлично! Что это такое? Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов. Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые). Для кого это? Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад. Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную. Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями. Да-да, сервис не бесплатен. Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса). Зачем это? С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего. Больше не нужно спорить создателям — какой блок где расположить. В этом им поможет Сумасшедшее яйцо. Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации. Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей. Как это работает? Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание. Насколько я понял — исполнительный скрипт работает на сервере CrazyEgg, поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая. Сколько это стоит? Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию. Расскажу подробнее о тарификации. 1. Бесплатная тестовая версия. Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте. 2. Базовая версия. В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта. Стоит базовый комплект — 9 долларов в месяц. В этот комплект включены все дополнительные функции. 3. Версия «Стандарт». В неё входит возможность отслеживания 25 000 посещений на 20 страницах. Вполне подходит для тестирования нового стартапа. Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора. 4. Версия «Плюс». Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц. Очень хороший тариф для крупных сервисов. Стоит 49 долларов в месяц. Довольно большие деньги за сервис, но они обычно с лихвой окупаются. 5. Версия «Про». Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах. Тариф подходит для монстров с большой посещаемостью и большим количеством страниц. Есть и аналоги Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле. 1. Google Analytics — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков. Очень подробная и полезная вещь. Рекомендую, т.к. сам пользуюсь им для этог ...

# %% [markdown]
# ## 2. Задание на выбор слов после "не " (1 балл)
#
# Вытащите из очищенного текста все слова, которые идут после "не ", кроме слов, начинающихся на гласную букву. Сама часть "не " не должна извлекаться.

# %%
re.findall('не ([^а, о, у, ы, е, я, э, ю, и]\w+)', text)
# Out:
# ['знаю',
#  'поленился',
#  'бесплатен',
#  'сайтов',
#  'хватает',
#  'нужно',
#  'сайта',
#  'лишним',
#  'нужно',
#  'потеряет',
#  'бесплатен',
#  'достаточно',
#  'подходит',
#  'поленился']

# %% [markdown]
# ## 3. Задание на выбор глаголов (1 балл)
#
# Попробуйте вытащить из очищенного текста как можно больше глаголов (минимум 40 с повоторениями), не перечисляя их в паттерне полностью. Можете токенизировать текст и использовать re.match, а можете использовать re.findall с \\b в начале и конце паттерна, чтобы не матчить части слов.
#
# В результате не должно быть не глаголов. Также постарайтесь сделать паттерн максимально коротким.

# %%
verbs = re.findall(r'\b\w+[иа]ть\b|\b\w+ся\b|\b\w+ал\b|\b\w+ет\b',text)
verbs
# Out:
# ['будет',
#  'работает',
#  'Запоминается',
#  'позволяет',
#  'отслеживать',
#  'выводить',
#  'совмещает',
#  'Разумеется',
#  'планировался',
#  'пользоваться',
#  'может',
#  'дает',
#  'знать',
#  'популяризировался',
#  'предполагает',
#  'написать',
#  'поленился',
#  'заплатить',
#  'потестировать',
#  'отслеживать',
#  'хватает',
#  'тасовать',
#  'спорить',
#  'расположить',
#  'поможет',
#  'поможет',
#  'располагать',
#  'зайдет',
#  'будет',
#  'вычислить',
#  'будет',
#  'приносить',
#  'работает',
#  'начнет',
#  'работает',
#  'потеряет',
#  'упоминал',
#  'имеет',
#  'Включает',
#  'отследить',
#  'Отличается',
#  'окупаются',
#  'имеет',
#  'отследить',
#  'поленился',
#  'собрал',
#  'использовал',
#  'собрал',
#  'находится',
#  'Использовать',
#  'кусаются',
#  'отбиваются',
#  'Использовать',
#  'помогает',
#  'повысить']

# %%
len(verbs)
# Out:
# 55

# %% [markdown]
# ## 4. Pymorphy vs Mystem (2 балла)

# %% [markdown]
# Лемматизируйте очищенный текст с помощью mystem и pymorphy. Сравните результаты: есть ли разница, что лучше.

# %% [markdown]
# Для пайморфи используйте токенизацию из mystem, чтобы исключить влияние токенизации на результат.

# %%
from pymystem3 import Mystem
import os, json
mystem = Mystem()
#получим общий для всех список токенов
tokens = [t['text'] for t in mystem.analyze(text)]

# %%
#получим список лемм для mystem
mystem = Mystem()
mystem_lemmas = mystem.lemmatize(text)

# %%
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()
#получим список лемм для pymorphy
words_analized = [morph.parse(token) for token in tokens]
pymorphy_lemmas = [word[0].normal_form for word in words_analized]
# Out:
# [[Parse(word='сегодняшняя', tag=OpencorporaTag('ADJF femn,sing,nomn'), normal_form='сегодняшний', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сегодняшняя', 382, 7),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='заметка', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='заметка', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'заметка', 8, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='будет', tag=OpencorporaTag('VERB,impf,intr sing,3per,futr,indc'), normal_form='быть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'будет', 587, 12),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='о', tag=OpencorporaTag('PREP'), normal_form='о', score=0.990985, methods_stack=((<DictionaryAnalyzer>, 'о', 2133, 0),)),
#   Parse(word='о', tag=OpencorporaTag('INTJ'), normal_form='о', score=0.009014, methods_stack=((<DictionaryAnalyzer>, 'о', 21, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='сервисе', tag=OpencorporaTag('NOUN,inan,masc sing,loct'), normal_form='сервис', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сервисе', 33, 5),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='отслеживания', tag=OpencorporaTag('NOUN,inan,neut,Sgtm sing,gent'), normal_form='отслеживание', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'отслеживания', 108, 1),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='активности', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='активность', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'активности', 13, 1),)),
#   Parse(word='активности', tag=OpencorporaTag('NOUN,inan,femn sing,datv'), normal_form='активность', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'активности', 13, 2),)),
#   Parse(word='активности', tag=OpencorporaTag('NOUN,inan,femn sing,loct'), normal_form='активность', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'активности', 13, 5),)),
#   Parse(word='активности', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='активность', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'активности', 13, 6),)),
#   Parse(word='активности', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='активность', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'активности', 13, 9),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='пользователя', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='пользователь', score=0.764705, methods_stack=((<DictionaryAnalyzer>, 'пользователя', 121, 1),)),
#   Parse(word='пользователя', tag=OpencorporaTag('NOUN,anim,masc sing,accs'), normal_form='пользователь', score=0.235294, methods_stack=((<DictionaryAnalyzer>, 'пользователя', 121, 3),))],
#  [Parse(word=' — ', tag=OpencorporaTag('PNCT'), normal_form=' — ', score=1.0, methods_stack=((<PunctuationAnalyzer>, ' — '),))],
#  [Parse(word='crazyegg', tag=OpencorporaTag('LATN'), normal_form='crazyegg', score=1.0, methods_stack=((<LatinAnalyzer>, 'CrazyEgg'),))],
#  [Parse(word='. ', tag=OpencorporaTag('PNCT'), normal_form='. ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '. '),))],
#  [Parse(word='я', tag=OpencorporaTag('NPRO,1per sing,nomn'), normal_form='я', score=0.2941176470588234, methods_stack=((<DictionaryAnalyzer>, 'я', 3100, 0),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,nomn'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,gent'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,datv'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,accs'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,ablt'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,loct'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,nomn'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,gent'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,datv'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,accs'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,ablt'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,loct'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,nomn'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,gent'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,datv'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,accs'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,ablt'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,loct'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Patr,Fixd,Abbr,Init sing,nomn'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Patr,Fixd,Abbr,Init sing,gent'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Patr,Fixd,Abbr,Init sing,datv'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Patr,Fixd,Abbr,Init sing,accs'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Patr,Fixd,Abbr,Init sing,ablt'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),)),
#   Parse(word='я', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Patr,Fixd,Abbr,Init sing,loct'), normal_form='я', score=0.02941176470588234, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'Я'),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='не', tag=OpencorporaTag('PRCL'), normal_form='не', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'не', 22, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='знаю', tag=OpencorporaTag('VERB,impf,tran sing,1per,pres,indc'), normal_form='знать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'знаю', 303, 1),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='кому', tag=OpencorporaTag('NOUN,inan,femn sing,accs'), normal_form='кома', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'кому', 55, 3),)),
#   Parse(word='кому', tag=OpencorporaTag('NOUN,inan,masc sing,datv'), normal_form='ком', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'кому', 551, 2),)),
#   Parse(word='кому', tag=OpencorporaTag('NPRO,masc sing,datv'), normal_form='кто', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'кому', 1742, 2),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='обязан', tag=OpencorporaTag('PRTS,perf,past,pssv masc,sing'), normal_form='обязать', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'обязан', 638, 71),)),
#   Parse(word='обязан', tag=OpencorporaTag('ADJS,Qual masc,sing'), normal_form='обязанный', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'обязан', 2190, 27),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='сервис', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='сервис', score=0.625, methods_stack=((<DictionaryAnalyzer>, 'сервис', 33, 0),)),
#   Parse(word='сервис', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='сервис', score=0.375, methods_stack=((<DictionaryAnalyzer>, 'сервис', 33, 3),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='таким', tag=OpencorporaTag('ADJF,Apro plur,datv'), normal_form='такой', score=0.805555, methods_stack=((<DictionaryAnalyzer>, 'таким', 1676, 22),)),
#   Parse(word='таким', tag=OpencorporaTag('ADJF,Apro masc,sing,ablt'), normal_form='такой', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'таким', 1676, 5),)),
#   Parse(word='таким', tag=OpencorporaTag('ADJF,Apro neut,sing,ablt'), normal_form='такой', score=0.027777, methods_stack=((<DictionaryAnalyzer>, 'таким', 1676, 18),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='говорящим', tag=OpencorporaTag('ADJF masc,sing,ablt'), normal_form='говорящий', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'говорящим', 162, 5),)),
#   Parse(word='говорящим', tag=OpencorporaTag('ADJF neut,sing,ablt'), normal_form='говорящий', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'говорящим', 162, 18),)),
#   Parse(word='говорящим', tag=OpencorporaTag('ADJF plur,datv'), normal_form='говорящий', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'говорящим', 162, 22),)),
#   Parse(word='говорящим', tag=OpencorporaTag('PRTF,impf,tran,pres,actv masc,sing,ablt'), normal_form='говорить', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'говорящим', 395, 18),)),
#   Parse(word='говорящим', tag=OpencorporaTag('PRTF,impf,tran,pres,actv neut,sing,ablt'), normal_form='говорить', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'говорящим', 395, 31),)),
#   Parse(word='говорящим', tag=OpencorporaTag('PRTF,impf,tran,pres,actv plur,datv'), normal_form='говорить', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'говорящим', 395, 35),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='именем', tag=OpencorporaTag('NOUN,inan,neut sing,ablt'), normal_form='имя', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'именем', 1647, 4),))],
#  [Parse(word=', ', tag=OpencorporaTag('PNCT'), normal_form=', ', score=1.0, methods_stack=((<PunctuationAnalyzer>, ', '),))],
#  [Parse(word='но', tag=OpencorporaTag('CONJ'), normal_form='но', score=0.998721, methods_stack=((<DictionaryAnalyzer>, 'но', 20, 0),)),
#   Parse(word='но', tag=OpencorporaTag('INTJ'), normal_form='но', score=0.001278, methods_stack=((<DictionaryAnalyzer>, 'но', 21, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='оно', tag=OpencorporaTag('NPRO,neut,3per,Anph sing,nomn'), normal_form='оно', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'оно', 2211, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='работает', tag=OpencorporaTag('VERB,impf,intr sing,3per,pres,indc'), normal_form='работать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'работает', 15, 5),))],
#  [Parse(word=', ', tag=OpencorporaTag('PNCT'), normal_form=', ', score=1.0, methods_stack=((<PunctuationAnalyzer>, ', '),))],
#  [Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#   Parse(word='и', tag=OpencorporaTag('INTJ'), normal_form='и', score=0.000436, methods_stack=((<DictionaryAnalyzer>, 'и', 21, 0),)),
#   Parse(word='и', tag=OpencorporaTag('PRCL'), normal_form='и', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 22, 0),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 12),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 13),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 14),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 15),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 16),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 17),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 18),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 19),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 20),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 21),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 22),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 23),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='хорошо', tag=OpencorporaTag('ADVB,Prdx'), normal_form='хорошо', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'хорошо', 385, 0),)),
#   Parse(word='хорошо', tag=OpencorporaTag('PRCL'), normal_form='хорошо', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'хорошо', 22, 0),)),
#   Parse(word='хорошо', tag=OpencorporaTag('PRED,pres'), normal_form='хорошо', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'хорошо', 242, 0),)),
#   Parse(word='хорошо', tag=OpencorporaTag('ADJS,Qual neut,sing'), normal_form='хороший', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'хорошо', 2998, 29),))],
#  [Parse(word='. ', tag=OpencorporaTag('PNCT'), normal_form='. ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '. '),))],
#  [Parse(word='запоминается', tag=OpencorporaTag('VERB,impf,intr sing,3per,pres,indc'), normal_form='запоминаться', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'запоминается', 224, 5),))],
#  [Parse(word='? ', tag=OpencorporaTag('PNCT'), normal_form='? ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '? '),))],
#  [Parse(word='отлично', tag=OpencorporaTag('ADVB'), normal_form='отлично', score=0.833333, methods_stack=((<DictionaryAnalyzer>, 'отлично', 3, 0),)),
#   Parse(word='отлично', tag=OpencorporaTag('ADJS,Qual neut,sing'), normal_form='отличный', score=0.166666, methods_stack=((<DictionaryAnalyzer>, 'отлично', 86, 56),))],
#  [Parse(word='! ', tag=OpencorporaTag('PNCT'), normal_form='! ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '! '),))],
#  [Parse(word='что', tag=OpencorporaTag('CONJ'), normal_form='что', score=0.791044, methods_stack=((<DictionaryAnalyzer>, 'что', 3046, 0),)),
#   Parse(word='что', tag=OpencorporaTag('NPRO,neut sing,accs'), normal_form='что', score=0.089552, methods_stack=((<DictionaryAnalyzer>, 'что', 3047, 3),)),
#   Parse(word='что', tag=OpencorporaTag('NPRO,neut sing,nomn'), normal_form='что', score=0.074626, methods_stack=((<DictionaryAnalyzer>, 'что', 3047, 0),)),
#   Parse(word='что', tag=OpencorporaTag('PRCL'), normal_form='что', score=0.02985, methods_stack=((<DictionaryAnalyzer>, 'что', 22, 0),)),
#   Parse(word='что', tag=OpencorporaTag('ADVB,Ques'), normal_form='что', score=0.014925, methods_stack=((<DictionaryAnalyzer>, 'что', 1130, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='это', tag=OpencorporaTag('PRCL'), normal_form='это', score=0.35, methods_stack=((<DictionaryAnalyzer>, 'это', 22, 0),)),
#   Parse(word='это', tag=OpencorporaTag('NPRO,neut sing,nomn'), normal_form='это', score=0.3, methods_stack=((<DictionaryAnalyzer>, 'это', 3098, 0),)),
#   Parse(word='это', tag=OpencorporaTag('NPRO,neut sing,accs'), normal_form='это', score=0.15, methods_stack=((<DictionaryAnalyzer>, 'это', 3098, 3),)),
#   Parse(word='это', tag=OpencorporaTag('ADJF,Apro,Subx,Anph neut,sing,accs'), normal_form='этот', score=0.15, methods_stack=((<DictionaryAnalyzer>, 'это', 3099, 16),)),
#   Parse(word='это', tag=OpencorporaTag('ADJF,Apro,Subx,Anph neut,sing,nomn'), normal_form='этот', score=0.05, methods_stack=((<DictionaryAnalyzer>, 'это', 3099, 13),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='такое', tag=OpencorporaTag('ADJF,Apro neut,sing,nomn'), normal_form='такой', score=0.571428, methods_stack=((<DictionaryAnalyzer>, 'такое', 1676, 14),)),
#   Parse(word='такое', tag=OpencorporaTag('ADJF,Apro neut,sing,accs'), normal_form='такой', score=0.428571, methods_stack=((<DictionaryAnalyzer>, 'такое', 1676, 17),))],
#  [Parse(word='? ', tag=OpencorporaTag('PNCT'), normal_form='? ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '? '),))],
#  [Parse(word='как', tag=OpencorporaTag('CONJ'), normal_form='как', score=0.875, methods_stack=((<DictionaryAnalyzer>, 'как', 1673, 0),)),
#   Parse(word='как', tag=OpencorporaTag('ADVB,Ques'), normal_form='как', score=0.09375, methods_stack=((<DictionaryAnalyzer>, 'как', 1674, 0),)),
#   Parse(word='как', tag=OpencorporaTag('PRCL'), normal_form='как', score=0.03125, methods_stack=((<DictionaryAnalyzer>, 'как', 22, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='уже', tag=OpencorporaTag('ADVB'), normal_form='уже', score=0.692307, methods_stack=((<DictionaryAnalyzer>, 'уже', 3, 0),)),
#   Parse(word='уже', tag=OpencorporaTag('PRCL'), normal_form='уже', score=0.153846, methods_stack=((<DictionaryAnalyzer>, 'уже', 22, 0),)),
#   Parse(word='уже', tag=OpencorporaTag('NOUN,anim,masc sing,loct'), normal_form='уж', score=0.076923, methods_stack=((<DictionaryAnalyzer>, 'уже', 231, 5),)),
#   Parse(word='уже', tag=OpencorporaTag('COMP,Qual'), normal_form='узкий', score=0.076923, methods_stack=((<DictionaryAnalyzer>, 'уже', 2947, 31),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='сказано', tag=OpencorporaTag('PRTS,perf,past,pssv neut,sing'), normal_form='сказать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сказано', 638, 73),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='выше', tag=OpencorporaTag('ADVB'), normal_form='выше', score=0.285714, methods_stack=((<DictionaryAnalyzer>, 'выше', 3, 0),)),
#   Parse(word='выше', tag=OpencorporaTag('COMP,Qual'), normal_form='высокий', score=0.285714, methods_stack=((<DictionaryAnalyzer>, 'выше', 1086, 58),)),
#   Parse(word='выше', tag=OpencorporaTag('PREP'), normal_form='выше', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'выше', 24, 0),)),
#   Parse(word='выше', tag=OpencorporaTag('NOUN,inan,femn,Sgtm,Geox sing,datv'), normal_form='выша', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'выше', 284, 2),)),
#   Parse(word='выше', tag=OpencorporaTag('NOUN,inan,femn,Sgtm,Geox sing,loct'), normal_form='выша', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'выше', 284, 6),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='это', tag=OpencorporaTag('PRCL'), normal_form='это', score=0.35, methods_stack=((<DictionaryAnalyzer>, 'это', 22, 0),)),
#   Parse(word='это', tag=OpencorporaTag('NPRO,neut sing,nomn'), normal_form='это', score=0.3, methods_stack=((<DictionaryAnalyzer>, 'это', 3098, 0),)),
#   Parse(word='это', tag=OpencorporaTag('NPRO,neut sing,accs'), normal_form='это', score=0.15, methods_stack=((<DictionaryAnalyzer>, 'это', 3098, 3),)),
#   Parse(word='это', tag=OpencorporaTag('ADJF,Apro,Subx,Anph neut,sing,accs'), normal_form='этот', score=0.15, methods_stack=((<DictionaryAnalyzer>, 'это', 3099, 16),)),
#   Parse(word='это', tag=OpencorporaTag('ADJF,Apro,Subx,Anph neut,sing,nomn'), normal_form='этот', score=0.05, methods_stack=((<DictionaryAnalyzer>, 'это', 3099, 13),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='сервис', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='сервис', score=0.625, methods_stack=((<DictionaryAnalyzer>, 'сервис', 33, 0),)),
#   Parse(word='сервис', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='сервис', score=0.375, methods_stack=((<DictionaryAnalyzer>, 'сервис', 33, 3),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='для', tag=OpencorporaTag('PREP'), normal_form='для', score=0.99984, methods_stack=((<DictionaryAnalyzer>, 'для', 24, 0),)),
#   Parse(word='для', tag=OpencorporaTag('GRND,impf,tran pres'), normal_form='длить', score=0.00016, methods_stack=((<DictionaryAnalyzer>, 'для', 463, 94),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='отслеживания', tag=OpencorporaTag('NOUN,inan,neut,Sgtm sing,gent'), normal_form='отслеживание', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'отслеживания', 108, 1),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='перемещения', tag=OpencorporaTag('NOUN,inan,neut sing,gent'), normal_form='перемещение', score=0.882352, methods_stack=((<DictionaryAnalyzer>, 'перемещения', 76, 2),)),
#   Parse(word='перемещения', tag=OpencorporaTag('NOUN,inan,neut plur,nomn'), normal_form='перемещение', score=0.058823, methods_stack=((<DictionaryAnalyzer>, 'перемещения', 76, 13),)),
#   Parse(word='перемещения', tag=OpencorporaTag('NOUN,inan,neut plur,accs'), normal_form='перемещение', score=0.058823, methods_stack=((<DictionaryAnalyzer>, 'перемещения', 76, 18),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='пользователей', tag=OpencorporaTag('NOUN,anim,masc plur,gent'), normal_form='пользователь', score=0.87, methods_stack=((<DictionaryAnalyzer>, 'пользователей', 121, 7),)),
#   Parse(word='пользователей', tag=OpencorporaTag('NOUN,anim,masc plur,accs'), normal_form='пользователь', score=0.13, methods_stack=((<DictionaryAnalyzer>, 'пользователей', 121, 9),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='по', tag=OpencorporaTag('PREP'), normal_form='по', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'по', 24, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='сайту', tag=OpencorporaTag('NOUN,inan,masc sing,datv'), normal_form='сайт', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сайту', 33, 2),))],
#  [Parse(word=' — ', tag=OpencorporaTag('PNCT'), normal_form=' — ', score=1.0, methods_stack=((<PunctuationAnalyzer>, ' — '),))],
#  [Parse(word='кто', tag=OpencorporaTag('NPRO,masc sing,nomn'), normal_form='кто', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'кто', 1742, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='куда', tag=OpencorporaTag('NOUN,inan,femn,Sgtm,Geox sing,nomn'), normal_form='куда', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'куда', 35, 0),)),
#   Parse(word='куда', tag=OpencorporaTag('ADVB,Ques'), normal_form='куда', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'куда', 1130, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='кликнул', tag=OpencorporaTag('VERB,perf,tran masc,sing,past,indc'), normal_form='кликнуть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'кликнул', 295, 1),))],
#  [Parse(word=', ', tag=OpencorporaTag('PNCT'), normal_form=', ', score=1.0, methods_stack=((<PunctuationAnalyzer>, ', '),))],
#  [Parse(word='какие', tag=OpencorporaTag('ADJF,Apro plur,nomn'), normal_form='какой', score=0.8, methods_stack=((<DictionaryAnalyzer>, 'какие', 1676, 20),)),
#   Parse(word='какие', tag=OpencorporaTag('ADJF,Apro inan,plur,accs'), normal_form='какой', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'какие', 1676, 23),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='ссылки', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='ссылка', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'ссылки', 8, 1),)),
#   Parse(word='ссылки', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='ссылка', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'ссылки', 8, 7),)),
#   Parse(word='ссылки', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='ссылка', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'ссылки', 8, 10),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='наиболее', tag=OpencorporaTag('ADVB'), normal_form='наиболее', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'наиболее', 3, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='популярные', tag=OpencorporaTag('ADJF,Qual plur,nomn'), normal_form='популярный', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'популярные', 214, 20),)),
#   Parse(word='популярные', tag=OpencorporaTag('ADJF,Qual inan,plur,accs'), normal_form='популярный', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'популярные', 214, 24),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#   Parse(word='и', tag=OpencorporaTag('INTJ'), normal_form='и', score=0.000436, methods_stack=((<DictionaryAnalyzer>, 'и', 21, 0),)),
#   Parse(word='и', tag=OpencorporaTag('PRCL'), normal_form='и', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 22, 0),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 12),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 13),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 14),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 15),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 16),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 17),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 18),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 19),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 20),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 21),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 22),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 23),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='тому', tag=OpencorporaTag('ADJF,Apro,Subx,Anph masc,sing,datv'), normal_form='тот', score=0.285714, methods_stack=((<DictionaryAnalyzer>, 'тому', 2900, 2),)),
#   Parse(word='тому', tag=OpencorporaTag('ADJF,Apro,Subx,Anph neut,sing,datv'), normal_form='тот', score=0.285714, methods_stack=((<DictionaryAnalyzer>, 'тому', 2900, 15),)),
#   Parse(word='тому', tag=OpencorporaTag('NOUN,anim,masc,Name sing,datv'), normal_form='том', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'тому', 26, 2),)),
#   Parse(word='тому', tag=OpencorporaTag('NOUN,anim,femn,Name sing,accs'), normal_form='тома', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'тому', 68, 3),)),
#   Parse(word='тому', tag=OpencorporaTag('NOUN,inan,masc sing,datv'), normal_form='том', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'тому', 2893, 2),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='подобная', tag=OpencorporaTag('ADJF,Subx,Qual femn,sing,nomn'), normal_form='подобный', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'подобная', 2408, 7),))],
#  [Parse(word=', ', tag=OpencorporaTag('PNCT'), normal_form=', ', score=1.0, methods_stack=((<PunctuationAnalyzer>, ', '),))],
#  [Parse(word='разнородная', tag=OpencorporaTag('ADJF,Qual femn,sing,nomn'), normal_form='разнородный', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'разнородная', 12, 7),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='информация', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='информация', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'информация', 40, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='для', tag=OpencorporaTag('PREP'), normal_form='для', score=0.99984, methods_stack=((<DictionaryAnalyzer>, 'для', 24, 0),)),
#   Parse(word='для', tag=OpencorporaTag('GRND,impf,tran pres'), normal_form='длить', score=0.00016, methods_stack=((<DictionaryAnalyzer>, 'для', 463, 94),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='юзабилистов', tag=OpencorporaTag('NOUN,inan,masc plur,gent'), normal_form='юзабилист', score=0.5001871958068139, methods_stack=((<DictionaryAnalyzer>, 'листов', 1614, 8), (<UnknownPrefixAnalyzer>, 'юзаби'))),
#   Parse(word='юзабилистов', tag=OpencorporaTag('NOUN,anim,masc plur,gent'), normal_form='юзабилист', score=0.24859603144889553, methods_stack=((<FakeDictionary>, 'юзабилистов', 52, 7), (<KnownSuffixAnalyzer>, 'истов'))),
#   Parse(word='юзабилистов', tag=OpencorporaTag('NOUN,anim,masc plur,accs'), normal_form='юзабилист', score=0.24859603144889553, methods_stack=((<FakeDictionary>, 'юзабилистов', 52, 9), (<KnownSuffixAnalyzer>, 'истов'))),
#   Parse(word='юзабилистов', tag=OpencorporaTag('ADJS,Qual masc,sing'), normal_form='юзабилистовый', score=0.0018719580681392737, methods_stack=((<FakeDictionary>, 'юзабилистов', 4, 27), (<KnownSuffixAnalyzer>, 'истов'))),
#   Parse(word='юзабилистов', tag=OpencorporaTag('ADJF,Poss masc,sing,nomn'), normal_form='юзабилистов', score=0.00037439161362785476, methods_stack=((<FakeDictionary>, 'юзабилистов', 99, 0), (<KnownSuffixAnalyzer>, 'истов'))),
#   Parse(word='юзабилистов', tag=OpencorporaTag('ADJF,Poss inan,masc,sing,accs'), normal_form='юзабилистов', score=0.00037439161362785476, methods_stack=((<FakeDictionary>, 'юзабилистов', 99, 4), (<KnownSuffixAnalyzer>, 'истов')))],
#  [Parse(word='. ', tag=OpencorporaTag('PNCT'), normal_form='. ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '. '),))],
#  [Parse(word='сервис', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='сервис', score=0.625, methods_stack=((<DictionaryAnalyzer>, 'сервис', 33, 0),)),
#   Parse(word='сервис', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='сервис', score=0.375, methods_stack=((<DictionaryAnalyzer>, 'сервис', 33, 3),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='позволяет', tag=OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'), normal_form='позволять', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'позволяет', 206, 5),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='отслеживать', tag=OpencorporaTag('INFN,impf,tran'), normal_form='отслеживать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'отслеживать', 206, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='активность', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='активность', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'активность', 13, 0),)),
#   Parse(word='активность', tag=OpencorporaTag('NOUN,inan,femn sing,accs'), normal_form='активность', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'активность', 13, 3),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='определённых', tag=OpencorporaTag('ADJF,Qual plur,gent'), normal_form='определённый', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'определённых', 12, 21),)),
#   Parse(word='определённых', tag=OpencorporaTag('ADJF,Qual anim,plur,accs'), normal_form='определённый', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'определённых', 12, 23),)),
#   Parse(word='определённых', tag=OpencorporaTag('ADJF,Qual plur,loct'), normal_form='определённый', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'определённых', 12, 26),)),
#   Parse(word='определённых', tag=OpencorporaTag('PRTF,perf,tran,past,pssv plur,gent'), normal_form='определить', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'определённых', 720, 63),)),
#   Parse(word='определённых', tag=OpencorporaTag('PRTF,perf,tran,past,pssv anim,plur,accs'), normal_form='определить', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'определённых', 720, 65),)),
#   Parse(word='определённых', tag=OpencorporaTag('PRTF,perf,tran,past,pssv plur,loct'), normal_form='определить', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'определённых', 720, 68),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='пользователей', tag=OpencorporaTag('NOUN,anim,masc plur,gent'), normal_form='пользователь', score=0.87, methods_stack=((<DictionaryAnalyzer>, 'пользователей', 121, 7),)),
#   Parse(word='пользователей', tag=OpencorporaTag('NOUN,anim,masc plur,accs'), normal_form='пользователь', score=0.13, methods_stack=((<DictionaryAnalyzer>, 'пользователей', 121, 9),))],
#  [Parse(word=', ', tag=OpencorporaTag('PNCT'), normal_form=', ', score=1.0, methods_stack=((<PunctuationAnalyzer>, ', '),))],
#  [Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)),
#   Parse(word='и', tag=OpencorporaTag('INTJ'), normal_form='и', score=0.000436, methods_stack=((<DictionaryAnalyzer>, 'и', 21, 0),)),
#   Parse(word='и', tag=OpencorporaTag('PRCL'), normal_form='и', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 22, 0),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 12),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 13),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 14),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 15),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 16),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 17),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 18),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 19),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 20),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 21),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 22),)),
#   Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 23),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='выводить', tag=OpencorporaTag('INFN,perf,tran'), normal_form='выводить', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'выводить', 935, 0),)),
#   Parse(word='выводить', tag=OpencorporaTag('INFN,impf,tran'), normal_form='выводить', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'выводить', 410, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='эти', tag=OpencorporaTag('ADJF,Apro,Subx,Anph plur,nomn'), normal_form='этот', score=0.571428, methods_stack=((<DictionaryAnalyzer>, 'эти', 3099, 19),)),
#   Parse(word='эти', tag=OpencorporaTag('ADJF,Apro,Subx,Anph inan,plur,accs'), normal_form='этот', score=0.428571, methods_stack=((<DictionaryAnalyzer>, 'эти', 3099, 22),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='данные', tag=OpencorporaTag('PRTF,perf,tran,past,pssv plur,nomn'), normal_form='дать', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'данные', 843, 62),)),
#   Parse(word='данные', tag=OpencorporaTag('PRTF,perf,tran,past,pssv inan,plur,accs'), normal_form='дать', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'данные', 843, 66),)),
#   Parse(word='данные', tag=OpencorporaTag('NOUN,inan,GNdr,Pltm plur,nomn'), normal_form='данные', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'данные', 151, 0),)),
#   Parse(word='данные', tag=OpencorporaTag('NOUN,inan,GNdr,Pltm plur,accs'), normal_form='данные', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'данные', 151, 3),)),
#   Parse(word='данные', tag=OpencorporaTag('ADJF,Apro plur,nomn'), normal_form='данный', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'данные', 1245, 19),)),
#   Parse(word='данные', tag=OpencorporaTag('ADJF,Apro inan,plur,accs'), normal_form='данный', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'данные', 1245, 22),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 20),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 21),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 22),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 23),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 24),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 25),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 26),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 27),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 28),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 29),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 30),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 31),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='различных', tag=OpencorporaTag('ADJF,Qual plur,gent'), normal_form='различный', score=0.795454, methods_stack=((<DictionaryAnalyzer>, 'различных', 12, 21),)),
#   Parse(word='различных', tag=OpencorporaTag('ADJF,Qual plur,loct'), normal_form='различный', score=0.181818, methods_stack=((<DictionaryAnalyzer>, 'различных', 12, 26),)),
#   Parse(word='различных', tag=OpencorporaTag('ADJF,Qual anim,plur,accs'), normal_form='различный', score=0.022727, methods_stack=((<DictionaryAnalyzer>, 'различных', 12, 23),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='формах', tag=OpencorporaTag('NOUN,inan,femn plur,loct'), normal_form='форма', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'формах', 55, 12),))],
#  [Parse(word=': «', tag=OpencorporaTag('PNCT'), normal_form=': «', score=1.0, methods_stack=((<PunctuationAnalyzer>, ': «'),))],
#  [Parse(word='инфракрасная', tag=OpencorporaTag('ADJF femn,sing,nomn'), normal_form='инфракрасный', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'инфракрасная', 69, 7),))],
#  [Parse(word='» — ', tag=OpencorporaTag('PNCT'), normal_form='» — ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '» — '),))],
#  [Parse(word='где', tag=OpencorporaTag('ADVB,Ques'), normal_form='где', score=0.636363, methods_stack=((<DictionaryAnalyzer>, 'где', 1130, 0),)),
#   Parse(word='где', tag=OpencorporaTag('CONJ'), normal_form='где', score=0.363636, methods_stack=((<DictionaryAnalyzer>, 'где', 20, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='чем', tag=OpencorporaTag('CONJ'), normal_form='чем', score=0.692307, methods_stack=((<DictionaryAnalyzer>, 'чем', 20, 0),)),
#   Parse(word='чем', tag=OpencorporaTag('NPRO,neut sing,ablt'), normal_form='что', score=0.153846, methods_stack=((<DictionaryAnalyzer>, 'чем', 3047, 4),)),
#   Parse(word='чём', tag=OpencorporaTag('NPRO,neut sing,loct'), normal_form='что', score=0.153846, methods_stack=((<DictionaryAnalyzer>, 'чём', 3047, 5),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
# ...
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='тариф', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='тариф', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'тариф', 33, 0),)),
#   Parse(word='тариф', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='тариф', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'тариф', 33, 3),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='для', tag=OpencorporaTag('PREP'), normal_form='для', score=0.99984, methods_stack=((<DictionaryAnalyzer>, 'для', 24, 0),)),
#   Parse(word='для', tag=OpencorporaTag('GRND,impf,tran pres'), normal_form='длить', score=0.00016, methods_stack=((<DictionaryAnalyzer>, 'для', 463, 94),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='крупных', tag=OpencorporaTag('ADJF,Qual plur,gent'), normal_form='крупный', score=0.807692, methods_stack=((<DictionaryAnalyzer>, 'крупных', 214, 21),)),
#   Parse(word='крупных', tag=OpencorporaTag('ADJF,Qual plur,loct'), normal_form='крупный', score=0.115384, methods_stack=((<DictionaryAnalyzer>, 'крупных', 214, 26),)),
#   Parse(word='крупных', tag=OpencorporaTag('ADJF,Qual anim,plur,accs'), normal_form='крупный', score=0.076923, methods_stack=((<DictionaryAnalyzer>, 'крупных', 214, 23),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='сервисов', tag=OpencorporaTag('NOUN,inan,masc plur,gent'), normal_form='сервис', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сервисов', 33, 7),))],
#  [Parse(word='. ', tag=OpencorporaTag('PNCT'), normal_form='. ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '. '),))],
#  [Parse(word='стоит', tag=OpencorporaTag('VERB,impf,intr,Impe sing,pres,indc'), normal_form='стоить', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стоит', 1304, 2),)),
#   Parse(word='стоит', tag=OpencorporaTag('VERB,impf,intr sing,3per,pres,indc'), normal_form='стоять', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стоит', 2176, 5),)),
#   Parse(word='стоит', tag=OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'), normal_form='стоить', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стоит', 2829, 5),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='49', tag=OpencorporaTag('NUMB,intg'), normal_form='49', score=1.0, methods_stack=((<NumberAnalyzer>, '49'),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='долларов', tag=OpencorporaTag('NOUN,inan,masc plur,gent'), normal_form='доллар', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'долларов', 1313, 7),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 20),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 21),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 22),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 23),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 24),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 25),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 26),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 27),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 28),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 29),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 30),)),
#   Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 31),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='месяц', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='месяц', score=0.84, methods_stack=((<DictionaryAnalyzer>, 'месяц', 71, 3),)),
#   Parse(word='месяц', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='месяц', score=0.16, methods_stack=((<DictionaryAnalyzer>, 'месяц', 71, 0),))],
#  [Parse(word='. ', tag=OpencorporaTag('PNCT'), normal_form='. ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '. '),))],
#  [Parse(word='довольно', tag=OpencorporaTag('ADVB,Prdx'), normal_form='довольно', score=0.96, methods_stack=((<DictionaryAnalyzer>, 'довольно', 385, 0),)),
#   Parse(word='довольно', tag=OpencorporaTag('ADJS,Qual neut,sing'), normal_form='довольный', score=0.04, methods_stack=((<DictionaryAnalyzer>, 'довольно', 216, 56),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='большие', tag=OpencorporaTag('ADJF,Qual plur,nomn'), normal_form='большой', score=0.4, methods_stack=((<DictionaryAnalyzer>, 'большие', 507, 20),)),
#   Parse(word='большие', tag=OpencorporaTag('ADJF plur,nomn'), normal_form='больший', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'большие', 506, 20),)),
#   Parse(word='большие', tag=OpencorporaTag('ADJF inan,plur,accs'), normal_form='больший', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'большие', 506, 24),)),
#   Parse(word='большие', tag=OpencorporaTag('ADJF,Qual inan,plur,accs'), normal_form='большой', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'большие', 507, 24),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='деньги', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='деньга', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'деньги', 1268, 1),)),
#   Parse(word='деньги', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='деньга', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'деньги', 1268, 7),)),
#   Parse(word='деньги', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='деньга', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'деньги', 1268, 10),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='за', tag=OpencorporaTag('PREP'), normal_form='за', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'за', 24, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='сервис', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='сервис', score=0.625, methods_stack=((<DictionaryAnalyzer>, 'сервис', 33, 0),)),
#   Parse(word='сервис', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='сервис', score=0.375, methods_stack=((<DictionaryAnalyzer>, 'сервис', 33, 3),))],
#  [Parse(word=', ', tag=OpencorporaTag('PNCT'), normal_form=', ', score=1.0, methods_stack=((<PunctuationAnalyzer>, ', '),))],
#  [Parse(word='но', tag=OpencorporaTag('CONJ'), normal_form='но', score=0.998721, methods_stack=((<DictionaryAnalyzer>, 'но', 20, 0),)),
#   Parse(word='но', tag=OpencorporaTag('INTJ'), normal_form='но', score=0.001278, methods_stack=((<DictionaryAnalyzer>, 'но', 21, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='они', tag=OpencorporaTag('NPRO,3per,Anph plur,nomn'), normal_form='они', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'они', 2210, 0),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='обычно', tag=OpencorporaTag('ADVB'), normal_form='обычно', score=0.962962, methods_stack=((<DictionaryAnalyzer>, 'обычно', 3, 0),)),
#   Parse(word='обычно', tag=OpencorporaTag('ADJS,Qual neut,sing'), normal_form='обычный', score=0.037037, methods_stack=((<DictionaryAnalyzer>, 'обычно', 86, 56),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='с', tag=OpencorporaTag('PREP'), normal_form='с', score=0.998363, methods_stack=((<DictionaryAnalyzer>, 'с', 375, 0),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,nomn'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 13),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,gent'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 14),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,datv'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 15),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,accs'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 16),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,ablt'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 17),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,loct'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 18),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,nomn'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 19),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,gent'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 20),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,datv'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 21),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,accs'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 22),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,ablt'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 23),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,loct'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 24),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,nomn'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 12),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,gent'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 13),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,datv'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 14),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,accs'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 15),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,ablt'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 16),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,loct'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 17),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr plur,nomn'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 18),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr plur,gent'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 19),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr plur,datv'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 20),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr plur,accs'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 21),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr plur,ablt'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 22),)),
#   Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr plur,loct'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 23),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='лихвой', tag=OpencorporaTag('NOUN,inan,femn sing,ablt'), normal_form='лихва', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'лихвой', 55, 4),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  [Parse(word='окупаются', tag=OpencorporaTag('VERB,impf,intr plur,3per,pres,indc'), normal_form='окупаться', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'окупаются', 224, 6),))],
#  [Parse(word='. ', tag=OpencorporaTag('PNCT'), normal_form='. ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '. '),))],
#  [Parse(word='5', tag=OpencorporaTag('NUMB,intg'), normal_form='5', score=1.0, methods_stack=((<NumberAnalyzer>, '5'),))],
#  [Parse(word='. ', tag=OpencorporaTag('PNCT'), normal_form='. ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '. '),))],
#  [Parse(word='версия', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='версия', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'версия', 40, 0),))],
#  [Parse(word=' «', tag=OpencorporaTag('PNCT'), normal_form=' «', score=1.0, methods_stack=((<PunctuationAnalyzer>, ' «'),))],
#  [Parse(word='про', tag=OpencorporaTag('PREP'), normal_form='про', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'про', 24, 0),))],
#  [Parse(word='»', tag=OpencorporaTag('PNCT'), normal_form='»', score=1.0, methods_stack=((<PunctuationAnalyzer>, '»'),))],
#  [Parse(word='. ', tag=OpencorporaTag('PNCT'), normal_form='. ', score=1.0, methods_stack=((<PunctuationAnalyzer>, '. '),))],
#  [Parse(word='стоит', tag=OpencorporaTag('VERB,impf,intr,Impe sing,pres,indc'), normal_form='стоить', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стоит', 1304, 2),)),
#   Parse(word='стоит', tag=OpencorporaTag('VERB,impf,intr sing,3per,pres,indc'), normal_form='стоять', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стоит', 2176, 5),)),
#   Parse(word='стоит', tag=OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'), normal_form='стоить', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стоит', 2829, 5),))],
#  [Parse(word=' ', tag=OpencorporaTag('UNKN'), normal_form=' ', score=1.0, methods_stack=((<UnknAnalyzer>, ' '),))],
#  ...]

# %%
# dataframe для сравнения
import pandas
drop_space = lambda tokens: [word for word in tokens if word!=' ']
compare_df = pandas.DataFrame(list(map(drop_space, [tokens, mystem_lemmas,pymorphy_lemmas])) ).T
compare_df.columns = ['orig', 'mystem', 'pymorphy']
compare_df.head()

# %%
# выделим оттуда все по-разному разобранные леммы (не считая разницы в больших/маленьких буквах)
difference_df = compare_df[compare_df.mystem.str.lower() != compare_df.pymorphy.str.lower()].reset_index(drop=True)
difference_df
# Out:
#             orig        mystem      pymorphy
# 0           кому           кто          кома
# 1         обязан     обязанный       обязать
# 2   определенных  определенный  определённый
# 3         данные        данные          дать
# 4       активнее       активно      активный
# 5         теплее         тепло        тёплый
# 6       активнее       активно      активный
# 7         больше         много       большой
# 8        конфети       конфеть      конфести
# 9    заполненнее   заполненный     залненный
# 10      активнее       активно      активный
# 11        первый        первый          один
# 12            им           они           имя
# 13         может         может          мочь
# 14          есть          быть          есть
# 15        деньги        деньги        деньга
# 16           пол           пол      половина
# 17       дешевых       дешевый       дешёвый
# 18          Дабы          дабы          даба
# 19        выбрав      выбирать       выбрать
# 20   включенными      включать      включить
# 21        Точнее         точно        точнее
# 22         всего           все         всего
# 23             т             т           том
# 24          того            то           тот
# 25        понять      понимать        понять
# 26         этого          этот           это
# 27        больше         много       большой
# 28         всего           все         всего
# 29        Больше        больше       большой
# ..           ...           ...           ...
# 53         Стоит        стоять        стоить
# 54        деньги        деньги        деньга
# 55         Стоит        стоять        стоить
# 56     отследить   отслеживать     отследить
# 57       большим       большой       больший
# 58          Есть          быть          есть
# 59        собрал      собирать       собрать
# 60           еще           еще           ещё
# 61       дешевле        дешево       дешёвый
# 62     счетчиков       счетчик       счётчик
# 63             т             т           том
# 64            им            он           имя
# 65         этого          этот           это
# 66           еще           еще           ещё
# 67             т             т           том
# 68     предпочел  предпочитать   предпочесть
# 69        врядли        врядли      врядлить
# 70        собрал      собирать       собрать
# 71        деньги        деньги        деньга
# 72        деньги        деньги        деньга
# 73         нужно        нужный         нужно
# 74      повысить      повышать      повысить
# 75    юзабилиста     юзабилист   юзабилистый
# 76      деньгами        деньги        деньга
# 77          этом          этот           это
# 78          есть          быть          есть
# 79     юзабилити     юзабилити     юзабилить
# 80     прошедшим     прошедший     прошедшее
# 81         всего          весь         всего
# 82      провести     проводить      провести
#
# [83 rows x 3 columns]

# %% [markdown]
# Если не учитывать различия, связанные с большими буквами в английский словах (которые, скорее всего, в одном случае никак не разбираются, а в другом просто ловеркейсаются), то можно увидеть следующие интересные различия:<br/>
# 1) приведение к единственному числу у pymorphy<br/>
# **деньги - деньга**<br/>
# 2) приведение к начальным формам глаголов у pymorphy(даже не глаголов) <br/>
# **данные - дать** <br/>
# **может - мочь** <br/>
# 3) проблемы с глаголами совершенного вида у mystem:<br/>
# **собрал - собирать	- собрать**<br/>
# **выбрав - выбирать	- выбрать** <br/>
# 4) интерпретация одной буквы/коротких слов у pymorphy (мб статистически это чаще опечатки?) <br/>
# **т	- т - том**<br/>
# **пол - пол	- половина**<br/>
# **им - они	- имя**<br/>
# 5)сравнительные формы у mystem:<br/>
# **активнее - активно - активный**<br/>
# **больше - много - большой**<br/>
# 6) Реакция на незнакомые слова (fake dictionary) у обоих лемматизаторов:<br/>
# **юзабилиста - юзабилист - юзабилистый**<br/>
# **юзабилити - юзабилити	- юзабилить**<br/>
# **конфети - конфеть - конфести**<br/>
# В целом, версия лемматизации mystem кажется мне более логичной и подходящей к большинству задач, т.к у pymorphy заметно сильно больше проблем при внимательном рассмотрении

# %% [markdown]
# ## 5. Разбиение на предложения в Mystem (2 балла)
#
# С помощью Mystem разделите текст из первого задания (очищенный) на предложения. Сравните разбиение с razdel.sentenize

# %% [markdown]
# **Предложения в mystem**

# %%
# записываем текст в файл, чтобы вызвать mystem из коробки
f = open('text.txt', 'w', encoding = 'utf-8')
f.write(text)
f.close()
# вызываем mystem
# !mystem -isc --format json text.txt text_parsed.txt
# получаем список параграфов
import json
t = [json.loads(line) for line in open('text_parsed.txt', encoding = 'utf-8')]
#вытаскиваем предложения
mystem_sentences = []
sent = ''
for i in t:
    for j in i:
        if j['text']!='\\s':
            sent+=j['text']
        elif j['text'] == '\\s':
            mystem_sentences.append(sent[:-1])
            sent = ''
mystem_sentences
# Out:
# ['Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg.',
#  'Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо.',
#  'Запоминается?',
#  'Отлично!',
#  'Что это такое?',
#  'Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.',
#  'Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые).',
#  'Для кого это?',
#  'Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад.',
#  'Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную.',
#  'Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.',
#  'Да-да, сервис не бесплатен.',
#  'Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса).',
#  'Зачем это?',
#  'С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего.',
#  'Больше не нужно спорить создателям — какой блок где расположить.',
#  'В этом им поможет Сумасшедшее яйцо.',
#  'Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации.',
#  'Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей.',
#  'Как это работает?',
#  'Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание.',
#  'Насколько я понял — исполнительный скрипт работает на сервере CrazyEgg, поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая.',
#  'Сколько это стоит?',
#  'Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию.',
#  'Расскажу подробнее о тарификации. 1.',
#  'Бесплатная тестовая версия.',
#  'Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте. 2.',
#  'Базовая версия.',
#  'В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта.',
#  'Стоит базовый комплект — 9 долларов в месяц.',
#  'В этот комплект включены все дополнительные функции. 3.',
#  'Версия «Стандарт».',
#  'В неё входит возможность отслеживания 25 000 посещений на 20 страницах.',
#  'Вполне подходит для тестирования нового стартапа.',
#  'Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора. 4.',
#  'Версия «Плюс».',
#  'Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц.',
#  'Очень хороший тариф для крупных сервисов.',
#  'Стоит 49 долларов в месяц.',
#  'Довольно большие деньги за сервис, но они обычно с лихвой окупаются. 5.',
#  'Версия «Про».',
#  'Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах.',
#  'Тариф подходит для монстров с большой посещаемостью и большим количеством страниц.',
#  'Есть и аналоги Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле. 1.',
#  'Google Analytics — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков.',
#  'Очень подробная и полезная вещь.',
#  'Рекомендую, т.к. сам пользуюсь им для этого блога. 2.',
#  'MapSurface — сам еще не использовал (т.к. предпочел CrazyEgg), но врядли будучи плохим сервис собрал бы множество положительных отзывов.',
#  'К сожалению он сейчас находится в статусе закрытой беты.',
#  'Вывод Использовать можно, и нужно.',
#  'Вот только тарифы довольно больно кусаются, но обычно эти деньги потом с лихвой отбиваются на повышении конвертации посетителей в деньги.',
#  'Использовать сервис нужно для тестирования рекламных мест и удобства отдельных страниц, что помогает опять же повысить конвертацию.',
#  'В общем и целом — полезная вещь для каждого владельца сайтов, а для юзабилиста вообще практически обязательна.',
#  'К счастью для людей, которые поиздержались деньгами в этом месяце — есть полезные аналоги.',
#  'Автор: Ярослав Бирзул (DezmASter).',
#  'Источник: Блог о юзабилити веб интерфейсов.',
#  'PS: Всех с прошедшим Новым годом!',
#  'От всей души желаю вам всего самого-самого лучшего, чего вы желаете только в самых сокровенных мечтах.']

# %% [markdown]
# **Предложения в natasha**

# %%
from razdel import sentenize
razdel_sents = list(sentenize(text))
razdel_sents = [sent.text for sent in razdel_sents]
razdel_sents
# Out:
# ['Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg.',
#  'Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо.',
#  'Запоминается?',
#  'Отлично!',
#  'Что это такое?',
#  'Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.',
#  'Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые).',
#  'Для кого это?',
#  'Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад.',
#  'Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную.',
#  'Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.',
#  'Да-да, сервис не бесплатен.',
#  'Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса).',
#  'Зачем это?',
#  'С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего.',
#  'Больше не нужно спорить создателям — какой блок где расположить.',
#  'В этом им поможет Сумасшедшее яйцо.',
#  'Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации.',
#  'Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей.',
#  'Как это работает?',
#  'Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание.',
#  'Насколько я понял — исполнительный скрипт работает на сервере CrazyEgg, поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая.',
#  'Сколько это стоит?',
#  'Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию.',
#  'Расскажу подробнее о тарификации.',
#  '1. Бесплатная тестовая версия.',
#  'Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте.',
#  '2. Базовая версия.',
#  'В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта.',
#  'Стоит базовый комплект — 9 долларов в месяц.',
#  'В этот комплект включены все дополнительные функции.',
#  '3. Версия «Стандарт».',
#  'В неё входит возможность отслеживания 25 000 посещений на 20 страницах.',
#  'Вполне подходит для тестирования нового стартапа.',
#  'Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора.',
#  '4. Версия «Плюс».',
#  'Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц.',
#  'Очень хороший тариф для крупных сервисов.',
#  'Стоит 49 долларов в месяц.',
#  'Довольно большие деньги за сервис, но они обычно с лихвой окупаются.',
#  '5. Версия «Про».',
#  'Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах.',
#  'Тариф подходит для монстров с большой посещаемостью и большим количеством страниц.',
#  'Есть и аналоги Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле.',
#  '1. Google Analytics — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков.',
#  'Очень подробная и полезная вещь.',
#  'Рекомендую, т.к. сам пользуюсь им для этого блога.',
#  '2. MapSurface — сам еще не использовал (т.к. предпочел CrazyEgg), но врядли будучи плохим сервис собрал бы множество положительных отзывов.',
#  'К сожалению он сейчас находится в статусе закрытой беты.',
#  'Вывод Использовать можно, и нужно.',
#  'Вот только тарифы довольно больно кусаются, но обычно эти деньги потом с лихвой отбиваются на повышении конвертации посетителей в деньги.',
#  'Использовать сервис нужно для тестирования рекламных мест и удобства отдельных страниц, что помогает опять же повысить конвертацию.',
#  'В общем и целом — полезная вещь для каждого владельца сайтов, а для юзабилиста вообще практически обязательна.',
#  'К счастью для людей, которые поиздержались деньгами в этом месяце — есть полезные аналоги.',
#  'Автор: Ярослав Бирзул (DezmASter).',
#  'Источник: Блог о юзабилити веб интерфейсов.',
#  'PS: Всех с прошедшим Новым годом!',
#  'От всей души желаю вам всего самого-самого лучшего, чего вы желаете только в самых сокровенных мечтах.',
#  'Удачно вам провести время.']

# %%
# датафрейм для сравнения
sent_df = pandas.DataFrame([mystem_sentences, razdel_sents] ).T
sent_df.columns = ['mystem', 'razdel']
sent_df.head()
# Out:
#                                               mystem  \
# 0  Сегодняшняя заметка будет о сервисе отслеживан...
# 1  Я не знаю кому обязан сервис таким говорящим и...
# 2                                      Запоминается?
# 3                                           Отлично!
# 4                                     Что это такое?
#
#                                               razdel
# 0  Сегодняшняя заметка будет о сервисе отслеживан...
# 1  Я не знаю кому обязан сервис таким говорящим и...
# 2                                      Запоминается?
# 3                                           Отлично!
# 4                                     Что это такое?

# %%
# выделим только различия
diff_df = sent_df[sent_df.mystem != sent_df.razdel].reset_index(drop=True)
diff_df
# Out:
#                                                mystem  \
# 0                Расскажу подробнее о тарификации. 1.
# 1                         Бесплатная тестовая версия.
# 2   Включает в себя возможность отслеживания 5 000...
# 3                                     Базовая версия.
# 4   В этот комплект включены все дополнительные фу...
# 5                                  Версия «Стандарт».
# 6   Стоит она 19 долларов в месяц, именно её я куп...
# 7                                      Версия «Плюс».
# 8   Довольно большие деньги за сервис, но они обыч...
# 9                                       Версия «Про».
# 10  Есть и аналоги Я не поленился, и собрал еще па...
# 11  Google Analytics — бесплатный сервис для сбора...
# 12  Рекомендую, т.к. сам пользуюсь им для этого бл...
# 13  MapSurface — сам еще не использовал (т.к. пред...
# 14                                               None
#
#                                                razdel
# 0                   Расскажу подробнее о тарификации.
# 1                      1. Бесплатная тестовая версия.
# 2   Включает в себя возможность отслеживания 5 000...
# 3                                  2. Базовая версия.
# 4   В этот комплект включены все дополнительные фу...
# 5                               3. Версия «Стандарт».
# 6   Стоит она 19 долларов в месяц, именно её я куп...
# 7                                   4. Версия «Плюс».
# 8   Довольно большие деньги за сервис, но они обыч...
# 9                                    5. Версия «Про».
# 10  Есть и аналоги Я не поленился, и собрал еще па...
# 11  1. Google Analytics — бесплатный сервис для сб...
# 12  Рекомендую, т.к. сам пользуюсь им для этого бл...
# 13  2. MapSurface — сам еще не использовал (т.к. п...
# 14                         Удачно вам провести время.

# %% [markdown]
# Как видно, основная проблема mystem проявилась при появлении нумерованных списков. Скорее всего, mystem не считает началом предложения отдельную цифру и включает ее в предыдущее, даже если она написана через точку

# %% [markdown]
# ## 6*. Дизамбигуация в Mystem (2 балла)

# %% [markdown]
# *необязательное задание на 10 баллов

# %% [markdown]
# Одна из фичей майстема - контекстная дизамбигуация (т.е. определение правильного разбора в зависимости от контекста).

# %% [markdown]
# Запустите mystem на очищенном тексте с дизамбигуацией и без и проверьте есть ли какие-то различия.

# %%
# -d для дизамбигуации
# !mystem -d -isc --format json text.txt parsed_disambig.txt

# %%
disambig = [json.loads(line) for line in open('parsed_disambig.txt', encoding = 'utf-8')]
disambig
# Out:
# [[{'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'сегодняшний'}],
#    'text': 'Сегодняшняя'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'заметка'}],
#    'text': 'заметка'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л', 'lex': 'быть'}],
#    'text': 'будет'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'сервис'}],
#    'text': 'сервисе'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,мн', 'lex': 'отслеживание'},
#     {'gr': 'S,сред,неод=род,ед', 'lex': 'отслеживание'},
#     {'gr': 'S,сред,неод=им,мн', 'lex': 'отслеживание'}],
#    'text': 'отслеживания'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,ед', 'lex': 'активность'},
#     {'gr': 'S,жен,неод=вин,мн', 'lex': 'активность'},
#     {'gr': 'S,жен,неод=дат,ед', 'lex': 'активность'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'активность'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'активность'}],
#    'text': 'активности'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,од=вин,ед', 'lex': 'пользователь'},
#     {'gr': 'S,муж,од=род,ед', 'lex': 'пользователь'}],
#    'text': 'пользователя'},
#   {'text': ' — '},
#   {'analysis': [], 'text': 'CrazyEgg'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'Я'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,пе=непрош,ед,изъяв,1-л', 'lex': 'знать'}],
#    'text': 'знаю'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,муж,од=дат', 'lex': 'кто'}], 'text': 'кому'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=ед,кр,муж', 'lex': 'обязанный'}], 'text': 'обязан'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'сервис'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'сервис'}],
#    'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=дат,мн', 'lex': 'такой'},
#     {'gr': 'APRO=твор,ед,муж', 'lex': 'такой'},
#     {'gr': 'APRO=твор,ед,сред', 'lex': 'такой'}],
#    'text': 'таким'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=дат,мн,полн', 'lex': 'говорящий'},
#     {'gr': 'A=твор,ед,полн,муж', 'lex': 'говорящий'},
#     {'gr': 'A=твор,ед,полн,сред', 'lex': 'говорящий'}],
#    'text': 'говорящим'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=твор,ед', 'lex': 'имя'}],
#    'text': 'именем'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,3-л,сред=им', 'lex': 'оно'}], 'text': 'оно'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,нп=непрош,ед,изъяв,3-л', 'lex': 'работать'}],
#    'text': 'работает'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=вводн', 'lex': 'хорошо'}], 'text': 'хорошо'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л,несов',
#      'lex': 'запоминаться'}],
#    'text': 'Запоминается'},
#   {'text': '? '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'отлично'}], 'text': 'Отлично'},
#   {'text': '! '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=вин', 'lex': 'что'},
#     {'gr': 'SPRO,ед,сред,неод=им', 'lex': 'что'}],
#    'text': 'Что'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=вин', 'lex': 'это'},
#     {'gr': 'SPRO,ед,сред,неод=им', 'lex': 'это'}],
#    'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=вин,ед,сред', 'lex': 'такой'},
#     {'gr': 'APRO=им,ед,сред', 'lex': 'такой'}],
#    'text': 'такое'},
#   {'text': '? '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADVPRO=', 'lex': 'как'}], 'text': 'Как'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'уже'}], 'text': 'уже'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,сов,пе=прош,ед,прич,кр,сред,страд',
#      'lex': 'сказать'}],
#    'text': 'сказано'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'выше'}], 'text': 'выше'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=вин', 'lex': 'это'},
#     {'gr': 'SPRO,ед,сред,неод=им', 'lex': 'это'}],
#    'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'сервис'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'сервис'}],
#    'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,мн', 'lex': 'отслеживание'},
#     {'gr': 'S,сред,неод=род,ед', 'lex': 'отслеживание'},
#     {'gr': 'S,сред,неод=им,мн', 'lex': 'отслеживание'}],
#    'text': 'отслеживания'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,мн', 'lex': 'перемещение'},
#     {'gr': 'S,сред,неод=род,ед', 'lex': 'перемещение'},
#     {'gr': 'S,сред,неод=им,мн', 'lex': 'перемещение'}],
#    'text': 'перемещения'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,од=вин,мн', 'lex': 'пользователь'},
#     {'gr': 'S,муж,од=род,мн', 'lex': 'пользователь'}],
#    'text': 'пользователей'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'по'}], 'text': 'по'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=дат,ед', 'lex': 'сайт'}], 'text': 'сайту'},
#   {'text': ' — '},
#   {'analysis': [{'gr': 'SPRO,ед,муж,од=им', 'lex': 'кто'}], 'text': 'кто'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADVPRO=', 'lex': 'куда'}], 'text': 'куда'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,сов,пе=прош,ед,изъяв,муж', 'lex': 'кликнуть'}],
#    'text': 'кликнул'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'APRO=им,мн', 'lex': 'какой'},
#     {'gr': 'APRO=вин,мн,неод', 'lex': 'какой'}],
#    'text': 'какие'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,мн', 'lex': 'ссылка'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'ссылка'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'ссылка'}],
#    'text': 'ссылки'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'наиболее'}], 'text': 'наиболее'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,мн,полн,неод', 'lex': 'популярный'},
#     {'gr': 'A=им,мн,полн', 'lex': 'популярный'}],
#    'text': 'популярные'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=дат,ед,муж', 'lex': 'тот'},
#     {'gr': 'APRO=дат,ед,сред', 'lex': 'тот'}],
#    'text': 'тому'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'подобный'}],
#    'text': 'подобная'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'разнородный'}],
#    'text': 'разнородная'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'информация'}],
#    'text': 'информация'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,од=вин,мн',
#      'lex': 'юзабилист',
#      'qual': 'bastard'},
#     {'gr': 'S,муж,од=род,мн', 'lex': 'юзабилист', 'qual': 'bastard'}],
#    'text': 'юзабилистов'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'сервис'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'сервис'}],
#    'text': 'Сервис'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,пе=непрош,ед,изъяв,3-л,несов', 'lex': 'позволять'}],
#    'text': 'позволяет'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V=инф,несов,пе', 'lex': 'отслеживать'}],
#    'text': 'отслеживать'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'активность'},
#     {'gr': 'S,жен,неод=им,ед', 'lex': 'активность'}],
#    'text': 'активность'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=пр,мн,полн', 'lex': 'определенный'},
#     {'gr': 'A=вин,мн,полн,од', 'lex': 'определенный'},
#     {'gr': 'A=род,мн,полн', 'lex': 'определенный'}],
#    'text': 'определенных'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,од=вин,мн', 'lex': 'пользователь'},
#     {'gr': 'S,муж,од=род,мн', 'lex': 'пользователь'}],
#    'text': 'пользователей'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V=инф,несов,пе', 'lex': 'выводить'}],
#    'text': 'выводить'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=им,мн', 'lex': 'этот'},
#     {'gr': 'APRO=вин,мн,неод', 'lex': 'этот'}],
#    'text': 'эти'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,мн,неод=вин', 'lex': 'данные'},
#     {'gr': 'S,мн,неод=им', 'lex': 'данные'}],
#    'text': 'данные'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=пр,мн,полн', 'lex': 'различный'},
#     {'gr': 'A=вин,мн,полн,од', 'lex': 'различный'},
#     {'gr': 'A=род,мн,полн', 'lex': 'различный'}],
#    'text': 'различных'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,мн', 'lex': 'форма'}], 'text': 'формах'},
#   {'text': ': «'},
#   {'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'инфракрасный'}],
#    'text': 'инфракрасная'},
#   {'text': '» — '},
#   {'analysis': [{'gr': 'ADVPRO=', 'lex': 'где'}], 'text': 'где'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'чем'}], 'text': 'чем'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=срав', 'lex': 'активно'}], 'text': 'активнее'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'область'},
#     {'gr': 'S,жен,неод=им,ед', 'lex': 'область'}],
#    'text': 'область'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'тем'}], 'text': 'тем'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,3-л,жен=им', 'lex': 'она'}], 'text': 'она'},
#   {'text': ' «'},
#   {'analysis': [{'gr': 'ADV=срав', 'lex': 'тепло'}], 'text': 'теплее'},
#   {'text': '», '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,мн', 'lex': 'салют'},
#     {'gr': 'S,муж,неод=им,мн', 'lex': 'салют'}],
#    'text': 'салюты'},
#   {'text': ' ('},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'чем'}], 'text': 'чем'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=срав', 'lex': 'активно'}], 'text': 'активнее'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'область'},
#     {'gr': 'S,жен,неод=им,ед', 'lex': 'область'}],
#    'text': 'область'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'тем'}], 'text': 'тем'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=срав', 'lex': 'много'}], 'text': 'больше'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,ед',
#      'lex': 'конфеть',
#      'qual': 'bastard'},
#     {'gr': 'S,жен,неод=вин,мн', 'lex': 'конфеть', 'qual': 'bastard'},
#     {'gr': 'S,жен,неод=дат,ед', 'lex': 'конфеть', 'qual': 'bastard'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'конфеть', 'qual': 'bastard'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'конфеть', 'qual': 'bastard'}],
#    'text': 'конфети'},
#   {'text': '), '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,неод', 'lex': 'простой'},
#     {'gr': 'A=им,ед,полн,муж', 'lex': 'простой'},
#     {'gr': 'A=пр,ед,полн,жен', 'lex': 'простой'},
#     {'gr': 'A=дат,ед,полн,жен', 'lex': 'простой'},
#     {'gr': 'A=род,ед,полн,жен', 'lex': 'простой'},
#     {'gr': 'A=твор,ед,полн,жен', 'lex': 'простой'}],
#    'text': 'простой'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'список'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'список'}],
#    'text': 'список'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=твор,ед', 'lex': 'сортировка'}],
#    'text': 'сортировкой'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'по'}], 'text': 'по'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,ед', 'lex': 'активность'},
#     {'gr': 'S,жен,неод=вин,мн', 'lex': 'активность'},
#     {'gr': 'S,жен,неод=дат,ед', 'lex': 'активность'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'активность'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'активность'}],
#    'text': 'активности'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,мн', 'lex': 'колба'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'колба'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'колба'}],
#    'text': 'колбы'},
#   {'text': ' ('},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'чем'}], 'text': 'чем'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=срав', 'lex': 'заполненный', 'qual': 'bastard'}],
#    'text': 'заполненнее'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'колба'}], 'text': 'колба'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'тем'}], 'text': 'тем'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=срав', 'lex': 'активно'}], 'text': 'активнее'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'область'},
#     {'gr': 'S,жен,неод=им,ед', 'lex': 'область'}],
#    'text': 'область'},
#   {'text': '), '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,мн', 'lex': 'облако'},
#     {'gr': 'S,сред,неод=род,ед', 'lex': 'облако'},
#     {'gr': 'S,сред,неод=им,мн', 'lex': 'облако'}],
#    'text': 'облака'},
#   {'text': ' ('},
#   {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=вин,ед,муж,неод', 'lex': 'мой'},
#     {'gr': 'APRO=им,ед,муж', 'lex': 'мой'}],
#    'text': 'мой'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'взгляд'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'взгляд'}],
#    'text': 'взгляд'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'наиболее'}], 'text': 'наиболее'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,неод', 'lex': 'удобный'},
#     {'gr': 'A=им,ед,полн,муж', 'lex': 'удобный'}],
#    'text': 'удобный'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'вариант'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'вариант'}],
#    'text': 'вариант'},
#   {'text': ' — '},
#   {'analysis': [{'gr': 'V=непрош,ед,изъяв,3-л,несов,пе', 'lex': 'совмещать'}],
#    'text': 'совмещает'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO=пр', 'lex': 'себя'},
#     {'gr': 'SPRO=дат', 'lex': 'себя'}],
#    'text': 'себе'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=им,мн', 'lex': 'весь'},
#     {'gr': 'APRO=вин,ед,сред', 'lex': 'весь'},
#     {'gr': 'APRO=им,ед,сред', 'lex': 'весь'},
#     {'gr': 'APRO=вин,мн,неод', 'lex': 'весь'}],
#    'text': 'все'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=им,мн', 'lex': 'остальной'},
#     {'gr': 'APRO=вин,мн,неод', 'lex': 'остальной'}],
#    'text': 'остальные'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'вместе'}], 'text': 'вместе'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,сов,пе=прош,вин,мн,прич,полн,страд,неод',
#      'lex': 'взять'},
#     {'gr': 'V,сов,пе=прош,им,мн,прич,полн,страд', 'lex': 'взять'}],
#    'text': 'взятые'},
#   {'text': ')'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'PR=', 'lex': 'для'}], 'text': 'Для'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,муж,од=вин', 'lex': 'кто'},
#     {'gr': 'SPRO,ед,муж,од=род', 'lex': 'кто'}],
#    'text': 'кого'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=вин', 'lex': 'это'},
#     {'gr': 'SPRO,ед,сред,неод=им', 'lex': 'это'}],
#    'text': 'это'},
#   {'text': '? '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'разумеется'}], 'text': 'Разумеется'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'сервис'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'сервис'}],
#    'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'изначально'}], 'text': 'изначально'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,муж',
#      'lex': 'планироваться'}],
#    'text': 'планировался'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'как'}], 'text': 'как'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ANUM=вин,ед,муж,неод', 'lex': 'первый'},
#     {'gr': 'ANUM=им,ед,муж', 'lex': 'первый'}],
#    'text': 'первый'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,од=им,ед', 'lex': 'помощник'}],
#    'text': 'помощник'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,од=вин,мн',
#      'lex': 'юзабилист',
#      'qual': 'bastard'},
#     {'gr': 'S,муж,од=род,мн', 'lex': 'юзабилист', 'qual': 'bastard'}],
#    'text': 'юзабилистов'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,нп=инф', 'lex': 'пользоваться'}],
#    'text': 'пользоваться'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,мн=дат', 'lex': 'они'}], 'text': 'им'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV,вводн=', 'lex': 'может'}], 'text': 'может'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=вин,ед,муж,неод', 'lex': 'каждый'},
#     {'gr': 'APRO=им,ед,муж', 'lex': 'каждый'}],
#    'text': 'каждый'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'у'}], 'text': 'у'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,муж,од=вин', 'lex': 'кто'},
#     {'gr': 'SPRO,ед,муж,од=род', 'lex': 'кто'}],
#    'text': 'кого'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л,несов', 'lex': 'быть'},
#     {'gr': 'V,нп=непрош,мн,изъяв,3-л,несов', 'lex': 'быть'},
#     {'gr': 'V,нп=наст,мн,изъяв,1-л,несов', 'lex': 'быть'},
#     {'gr': 'V,нп=наст,ед,изъяв,1-л,несов', 'lex': 'быть'},
#     {'gr': 'V,нп=наст,мн,изъяв,2-л,несов', 'lex': 'быть'},
#     {'gr': 'V,нп=наст,ед,изъяв,2-л,несов', 'lex': 'быть'},
#     {'gr': 'V,нп=наст,мн,изъяв,3-л,несов', 'lex': 'быть'},
#     {'gr': 'V,нп=наст,ед,изъяв,3-л,несов', 'lex': 'быть'}],
#    'text': 'есть'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,мн,неод=вин', 'lex': 'деньги'},
#     {'gr': 'S,мн,неод=им', 'lex': 'деньги'}],
#    'text': 'деньги'},
#   {'text': ' — '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,неод', 'lex': 'интуитивный'},
#     {'gr': 'A=им,ед,полн,муж', 'lex': 'интуитивный'}],
#    'text': 'интуитивный'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'интерфейс'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'интерфейс'}],
#    'text': 'интерфейс'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,неод', 'lex': 'хороший'},
#     {'gr': 'A=им,ед,полн,муж', 'lex': 'хороший'}],
#    'text': 'хороший'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'дизайн'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'дизайн'}],
#    'text': 'дизайн'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,пе=непрош,ед,изъяв,3-л,несов', 'lex': 'давать'}],
#    'text': 'дает'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO=пр', 'lex': 'себя'},
#     {'gr': 'SPRO=дат', 'lex': 'себя'}],
#    'text': 'себе'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,пе=инф', 'lex': 'знать'}], 'text': 'знать'},
#   {'text': ' — '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'сервис'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'сервис'}],
#    'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'массово'}], 'text': 'массово'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,нп=прош,ед,изъяв,муж',
#      'lex': 'популяризироваться'}],
#    'text': 'популяризировался'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'NUM=вин', 'lex': 'пол'},
#     {'gr': 'NUM=им', 'lex': 'пол'}],
#    'text': 'пол'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,мн', 'lex': 'год'},
#     {'gr': 'S,муж,неод=род,ед', 'lex': 'год'},
#     {'gr': 'S,муж,неод=им,мн', 'lex': 'год'}],
#    'text': 'года'},
#   {'text': '-'},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'год'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'год'}],
#    'text': 'год'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'назад'}], 'text': 'назад'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'PR=', 'lex': 'относительно'}], 'text': 'Относительно'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,неод', 'lex': 'недорогой'},
#     {'gr': 'A=им,ед,полн,муж', 'lex': 'недорогой'},
#     {'gr': 'A=пр,ед,полн,жен', 'lex': 'недорогой'},
#     {'gr': 'A=дат,ед,полн,жен', 'lex': 'недорогой'},
#     {'gr': 'A=род,ед,полн,жен', 'lex': 'недорогой'},
#     {'gr': 'A=твор,ед,полн,жен', 'lex': 'недорогой'}],
#    'text': 'недорогой'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'уж'}], 'text': 'уж'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'точно'}], 'text': 'точно'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'из'}], 'text': 'из'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=пр,мн,полн', 'lex': 'дешевый'},
#     {'gr': 'A=вин,мн,полн,од', 'lex': 'дешевый'},
#     {'gr': 'A=род,мн,полн', 'lex': 'дешевый'}],
#    'text': 'дешевых'},
#   {'text': ' — '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'сервис'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'сервис'}],
#    'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,пе=непрош,ед,изъяв,3-л,несов',
#      'lex': 'предполагать'}],
#    'text': 'предполагает'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO=твор', 'lex': 'себя'}], 'text': 'собой'},
#   {'text': ' '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=пр,мн,полн', 'lex': 'платный'},
#     {'gr': 'A=вин,мн,полн,од', 'lex': 'платный'},
#     {'gr': 'A=род,мн,полн', 'lex': 'платный'}],
#    'text': 'платных'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,ед', 'lex': 'линия'},
#     {'gr': 'S,жен,неод=вин,мн', 'lex': 'линия'},
#     {'gr': 'S,жен,неод=дат,ед', 'lex': 'линия'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'линия'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'линия'}],
#    'text': 'линии'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ANUM=вин,ед,жен', 'lex': 'один'}], 'text': 'одну'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,жен', 'lex': 'бесплатный'}],
#    'text': 'бесплатную'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'дабы'}], 'text': 'Дабы'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,сов,пе=инф', 'lex': 'написать'}],
#    'text': 'написать'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=вин,ед,муж,неод', 'lex': 'этот'},
#     {'gr': 'APRO=им,ед,муж', 'lex': 'этот'}],
#    'text': 'этот'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'обзор'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'обзор'}],
#    'text': 'обзор'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,сов,нп=прош,ед,изъяв,муж', 'lex': 'полениться'}],
#    'text': 'поленился'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,сов,пе=инф', 'lex': 'заплатить'}],
#    'text': 'заплатить'},
#   {'text': ' '},
#   {'text': '19'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,мн', 'lex': 'доллар'}],
#    'text': 'долларов'},
#   {'text': ' ('},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'месяц'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'месяц'}],
#    'text': 'месяц'},
#   {'text': ') '},
#   {'analysis': [{'gr': 'V=прош,деепр,сов,пе', 'lex': 'выбирать'}],
#    'text': 'выбрав'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,неод', 'lex': 'средний'},
#     {'gr': 'A=им,ед,полн,муж', 'lex': 'средний'}],
#    'text': 'средний'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'вариант'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'вариант'}],
#    'text': 'вариант'},
#   {'text': ' — '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'NUM=', 'lex': 'несколько'},
#     {'gr': 'NUM=пр', 'lex': 'несколько'},
#     {'gr': 'NUM=род', 'lex': 'несколько'},
#     {'gr': 'NUM=вин,од', 'lex': 'несколько'}],
#    'text': 'нескольких'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,мн', 'lex': 'проект'}],
#    'text': 'проектов'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'с'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,пе=прош,твор,мн,прич,полн,сов,страд',
#      'lex': 'включать'}],
#    'text': 'включенными'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=твор,мн,полн', 'lex': 'дополнительный'}],
#    'text': 'дополнительными'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=твор,мн', 'lex': 'функция'}],
#    'text': 'функциями'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'PART=', 'lex': 'да'}], 'text': 'Да'},
#   {'text': '-'},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'да'}], 'text': 'да'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'сервис'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'сервис'}],
#    'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=ед,кр,муж', 'lex': 'бесплатный'}],
#    'text': 'бесплатен'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADV=срав', 'lex': 'точно'}], 'text': 'Точнее'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'бесплатный'}],
#    'text': 'бесплатная'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'возможность'},
#     {'gr': 'S,жен,неод=им,ед', 'lex': 'возможность'}],
#    'text': 'возможность'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,сов,пе=инф',
#      'lex': 'потестировать',
#      'qual': 'bastard'}],
#    'text': 'потестировать'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,пе=инф', 'lex': 'есть'}], 'text': 'есть'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'но'}], 'text': 'но'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,3-л,жен=им', 'lex': 'она'}], 'text': 'она'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'немного'}], 'text': 'немного'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,сов,пе=прош,ед,прич,кр,жен,страд',
#      'lex': 'обрезать'}],
#    'text': 'обрезана'},
#   {'text': ' ('},
#   {'analysis': [{'gr': 'ADV,прдк=', 'lex': 'можно'}], 'text': 'можно'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V=инф,несов,пе', 'lex': 'отслеживать'}],
#    'text': 'отслеживать'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'только'}], 'text': 'только'},
#   {'text': ' '},
#   {'text': '5000'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,од=вин,мн', 'lex': 'посетитель'},
#     {'gr': 'S,муж,од=род,мн', 'lex': 'посетитель'}],
#    'text': 'посетителей'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=род', 'lex': 'все'}],
#    'text': 'всего'},
#   {'text': ' '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,мн', 'lex': 'страница'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'страница'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'страница'}],
#    'text': 'страницы'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'сайт'}], 'text': 'сайте'},
#   {'text': ' ('},
#   {'analysis': [{'gr': 'S,сред,неод=вин,ед', 'lex': 'внимание'},
#     {'gr': 'S,сред,неод=им,ед', 'lex': 'внимание'}],
#    'text': 'внимание'},
#   {'text': ' — '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,мн', 'lex': 'страница'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'страница'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'страница'}],
#    'text': 'страницы'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'а'}], 'text': 'а'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,мн', 'lex': 'сайт'}], 'text': 'сайтов'},
#   {'text': '), '},
#   {'analysis': [{'gr': 'S,сокр=пр,мн', 'lex': 'т'},
#     {'gr': 'S,сокр=пр,ед', 'lex': 'т'},
#     {'gr': 'S,сокр=вин,мн', 'lex': 'т'},
#     {'gr': 'S,сокр=вин,ед', 'lex': 'т'},
#     {'gr': 'S,сокр=дат,мн', 'lex': 'т'},
#     {'gr': 'S,сокр=дат,ед', 'lex': 'т'},
#     {'gr': 'S,сокр=род,мн', 'lex': 'т'},
#     {'gr': 'S,сокр=род,ед', 'lex': 'т'},
#     {'gr': 'S,сокр=твор,мн', 'lex': 'т'},
#     {'gr': 'S,сокр=твор,ед', 'lex': 'т'},
#     {'gr': 'S,сокр=им,мн', 'lex': 'т'},
#     {'gr': 'S,сокр=им,ед', 'lex': 'т'}],
#    'text': 'т'},
#   {'text': '.'},
#   {'analysis': [{'gr': 'S,сокр=пр,мн', 'lex': 'е'},
#     {'gr': 'S,сокр=пр,ед', 'lex': 'е'},
#     {'gr': 'S,сокр=вин,мн', 'lex': 'е'},
#     {'gr': 'S,сокр=вин,ед', 'lex': 'е'},
#     {'gr': 'S,сокр=дат,мн', 'lex': 'е'},
#     {'gr': 'S,сокр=дат,ед', 'lex': 'е'},
#     {'gr': 'S,сокр=род,мн', 'lex': 'е'},
#     {'gr': 'S,сокр=род,ед', 'lex': 'е'},
#     {'gr': 'S,сокр=твор,мн', 'lex': 'е'},
#     {'gr': 'S,сокр=твор,ед', 'lex': 'е'},
#     {'gr': 'S,сокр=им,мн', 'lex': 'е'},
#     {'gr': 'S,сокр=им,ед', 'lex': 'е'}],
#    'text': 'е'},
#   {'text': '.'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'вполне'}], 'text': 'вполне'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов=непрош,ед,изъяв,3-л', 'lex': 'хватать'},
#     {'gr': 'V,несов=непрош,изъяв', 'lex': 'хватать'}],
#    'text': 'хватает'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=род', 'lex': 'то'}], 'text': 'того'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'чтобы'}], 'text': 'чтобы'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V=инф,сов', 'lex': 'понимать'}], 'text': 'понять'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'полезность'},
#     {'gr': 'S,жен,неод=им,ед', 'lex': 'полезность'}],
#    'text': 'полезность'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'сервис'}],
#    'text': 'сервиса'},
#   {'text': ')'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADVPRO=', 'lex': 'зачем'}], 'text': 'Зачем'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=вин', 'lex': 'это'},
#     {'gr': 'SPRO,ед,сред,неод=им', 'lex': 'это'}],
#    'text': 'это'},
#   {'text': '? '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'PR=', 'lex': 'с'}], 'text': 'С'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=твор,ед', 'lex': 'помощь'}],
#    'text': 'помощью'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=вин,ед,муж,од', 'lex': 'этот'},
#     {'gr': 'APRO=род,ед,муж', 'lex': 'этот'},
#     {'gr': 'APRO=род,ед,сред', 'lex': 'этот'}],
#    'text': 'этого'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'сервис'}],
#    'text': 'сервиса'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV,прдк=', 'lex': 'можно'}], 'text': 'можно'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,пе=инф', 'lex': 'тасовать'}],
#    'text': 'тасовать'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,мн', 'lex': 'блок'},
#     {'gr': 'S,муж,неод=им,мн', 'lex': 'блок'}],
#    'text': 'блоки'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'сайт'}], 'text': 'сайте'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'APRO=им,мн', 'lex': 'который'},
#     {'gr': 'APRO=вин,мн,неод', 'lex': 'который'}],
#    'text': 'которые'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=мн,кр', 'lex': 'полезный'}], 'text': 'полезны'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,од=дат,мн', 'lex': 'пользователь'}],
#    'text': 'пользователям'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=срав', 'lex': 'много'}], 'text': 'больше'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=род', 'lex': 'все'}],
#    'text': 'всего'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'больше'}], 'text': 'Больше'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV,прдк=', 'lex': 'нужно'}], 'text': 'нужно'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,нп=инф', 'lex': 'спорить'}],
#    'text': 'спорить'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,од=дат,мн', 'lex': 'создатель'}],
#    'text': 'создателям'},
#   {'text': ' — '},
#   {'analysis': [{'gr': 'APRO=пр,ед,жен', 'lex': 'какой'},
#     {'gr': 'APRO=дат,ед,жен', 'lex': 'какой'},
#     {'gr': 'APRO=род,ед,жен', 'lex': 'какой'},
#     {'gr': 'APRO=твор,ед,жен', 'lex': 'какой'},
#     {'gr': 'APRO=вин,ед,муж,неод', 'lex': 'какой'},
#     {'gr': 'APRO=им,ед,муж', 'lex': 'какой'}],
#    'text': 'какой'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'блок'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'блок'}],
#    'text': 'блок'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADVPRO=', 'lex': 'где'}], 'text': 'где'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V=инф,сов,пе', 'lex': 'располагать'}],
#    'text': 'расположить'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=пр', 'lex': 'это'}], 'text': 'этом'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,3-л,муж=твор', 'lex': 'он'}], 'text': 'им'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л,сов', 'lex': 'помогать'}],
#    'text': 'поможет'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,сред', 'lex': 'сумасшедший'},
#     {'gr': 'A=им,ед,полн,сред', 'lex': 'сумасшедший'}],
#    'text': 'Сумасшедшее'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,ед', 'lex': 'яйцо'},
#     {'gr': 'S,сред,неод=им,ед', 'lex': 'яйцо'}],
#    'text': 'яйцо'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'также'}], 'text': 'Также'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=вин,ед,муж,неод', 'lex': 'этот'},
#     {'gr': 'APRO=им,ед,муж', 'lex': 'этот'}],
#    'text': 'этот'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'сервис'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'сервис'}],
#    'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л,сов', 'lex': 'помогать'}],
#    'text': 'поможет'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,мн,2-л=дат', 'lex': 'вы'}], 'text': 'вам'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V=инф,сов', 'lex': 'понимать'}], 'text': 'понять'},
#   {'text': ' — '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=пр,ед,жен', 'lex': 'какой'},
#     {'gr': 'APRO=дат,ед,жен', 'lex': 'какой'},
#     {'gr': 'APRO=род,ед,жен', 'lex': 'какой'},
#     {'gr': 'APRO=твор,ед,жен', 'lex': 'какой'},
#     {'gr': 'APRO=вин,ед,муж,неод', 'lex': 'какой'},
#     {'gr': 'APRO=им,ед,муж', 'lex': 'какой'}],
#    'text': 'какой'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,ед', 'lex': 'зона'},
#     {'gr': 'S,жен,неод=дат,ед', 'lex': 'зона'}],
#    'text': 'зоне'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'сайт'}], 'text': 'сайта'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=срав,вводн', 'lex': 'хорошо'}], 'text': 'лучше'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=род', 'lex': 'все'}],
#    'text': 'всего'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V=инф,несов,нп', 'lex': 'располагать'}],
#    'text': 'располагать'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'реклама'}],
#    'text': 'рекламу'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'когда'}], 'text': 'когда'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=пр,ед,муж', 'lex': 'ваш'},
#     {'gr': 'APRO=пр,ед,сред', 'lex': 'ваш'}],
#    'text': 'вашем'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'сервис'}],
#    'text': 'сервисе'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'речь'},
#     {'gr': 'S,жен,неод=им,ед', 'lex': 'речь'}],
#    'text': 'речь'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,сов,нп=непрош,ед,изъяв,3-л', 'lex': 'зайти'}],
#    'text': 'зайдет'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,ед',
#      'lex': 'монетизация',
#      'qual': 'bastard'},
#     {'gr': 'S,жен,неод=вин,мн', 'lex': 'монетизация', 'qual': 'bastard'},
#     {'gr': 'S,жен,неод=дат,ед', 'lex': 'монетизация', 'qual': 'bastard'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'монетизация', 'qual': 'bastard'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'монетизация', 'qual': 'bastard'}],
#    'text': 'монетизации'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'PART=', 'lex': 'ведь'}], 'text': 'Ведь'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'альтруизм'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'альтруизм'}],
#    'text': 'альтруизм'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'это'}], 'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=вводн', 'lex': 'хорошо'}], 'text': 'хорошо'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'а'}], 'text': 'а'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,мн,неод=вин', 'lex': 'деньги'},
#     {'gr': 'S,мн,неод=им', 'lex': 'деньги'}],
#    'text': 'деньги'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,ед', 'lex': 'содержание'},
#     {'gr': 'S,сред,неод=им,ед', 'lex': 'содержание'}],
#    'text': 'содержание'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'сервис'}],
#    'text': 'сервиса'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=мн,кр', 'lex': 'нужный'}], 'text': 'нужны'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=дат,мн,полн', 'lex': 'лишний'},
#     {'gr': 'A=твор,ед,полн,муж', 'lex': 'лишний'},
#     {'gr': 'A=твор,ед,полн,сред', 'lex': 'лишний'}],
#    'text': 'лишним'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л', 'lex': 'быть'}],
#    'text': 'будет'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,пе=инф,сов', 'lex': 'вычислять'}],
#    'text': 'вычислить'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,мн', 'lex': 'зона'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'зона'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'зона'}],
#    'text': 'зоны'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADVPRO=', 'lex': 'где'}], 'text': 'где'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'реклама'}],
#    'text': 'реклама'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л', 'lex': 'быть'}],
#    'text': 'будет'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V=инф,несов,пе', 'lex': 'приносить'}],
#    'text': 'приносить'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,прев,жен', 'lex': 'большой'}],
#    'text': 'наибольшую'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'отдача'}],
#    'text': 'отдачу'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,прев,сред', 'lex': 'маленький'},
#     {'gr': 'A=им,ед,полн,прев,сред', 'lex': 'маленький'}],
#    'text': 'наименьшее'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,ед', 'lex': 'раздражение'},
#     {'gr': 'S,сред,неод=им,ед', 'lex': 'раздражение'}],
#    'text': 'раздражение'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'у'}], 'text': 'у'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,од=вин,мн', 'lex': 'пользователь'},
#     {'gr': 'S,муж,од=род,мн', 'lex': 'пользователь'}],
#    'text': 'пользователей'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADVPRO=', 'lex': 'как'}], 'text': 'Как'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=вин', 'lex': 'это'},
#     {'gr': 'SPRO,ед,сред,неод=им', 'lex': 'это'}],
#    'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,нп=непрош,ед,изъяв,3-л', 'lex': 'работать'}],
#    'text': 'работает'},
#   {'text': '? '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'APRO=пр,мн', 'lex': 'никакой'},
#     {'gr': 'APRO=род,мн', 'lex': 'никакой'},
#     {'gr': 'APRO=вин,мн,од', 'lex': 'никакой'}],
#    'text': 'Никаких'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=пр,мн,полн', 'lex': 'километровый'},
#     {'gr': 'A=вин,мн,полн,од', 'lex': 'километровый'},
#     {'gr': 'A=род,мн,полн', 'lex': 'километровый'}],
#    'text': 'километровых'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,мн', 'lex': 'скрипт'}],
#    'text': 'скриптов'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,пе=инф,несов', 'lex': 'вставлять'}],
#    'text': 'вставлять'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV,прдк=', 'lex': 'нужно'}], 'text': 'нужно'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'достаточно'}], 'text': 'достаточно'},
#   {'text': ' '},
#   {'analysis': [], 'text': 'вставиь'},
#   {'text': ' '},
#   {'text': '2'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,мн', 'lex': 'строчка'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'строчка'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'строчка'}],
#    'text': 'строчки'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,ед',
#      'lex': 'яваскрипт',
#      'qual': 'bastard'}],
#    'text': 'яваскрипта'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'сервис'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'сервис'}],
#    'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,пе=непрош,ед,изъяв,3-л,сов', 'lex': 'начинать'}],
#    'text': 'начнет'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,ед', 'lex': 'отслеживание'},
#     {'gr': 'S,сред,неод=им,ед', 'lex': 'отслеживание'}],
#    'text': 'отслеживание'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'насколько'}], 'text': 'Насколько'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V=прош,ед,изъяв,муж,сов', 'lex': 'понимать'}],
#    'text': 'понял'},
#   {'text': ' — '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,неод', 'lex': 'исполнительный'},
#     {'gr': 'A=им,ед,полн,муж', 'lex': 'исполнительный'}],
#    'text': 'исполнительный'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'скрипт'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'скрипт'}],
#    'text': 'скрипт'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,нп=непрош,ед,изъяв,3-л', 'lex': 'работать'}],
#    'text': 'работает'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'сервер'}],
#    'text': 'сервере'},
#   {'text': ' '},
#   {'analysis': [], 'text': 'CrazyEgg'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'ADVPRO=', 'lex': 'поэтому'}], 'text': 'поэтому'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=вин,ед,муж,неод', 'lex': 'ваш'},
#     {'gr': 'APRO=им,ед,муж', 'lex': 'ваш'}],
#    'text': 'ваш'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'сайт'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'сайт'}],
#    'text': 'сайт'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'от'}], 'text': 'от'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=род', 'lex': 'это'}],
#    'text': 'этого'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,ед', 'lex': 'производительность'},
#     {'gr': 'S,жен,неод=вин,мн', 'lex': 'производительность'},
#     {'gr': 'S,жен,неод=дат,ед', 'lex': 'производительность'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'производительность'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'производительность'}],
#    'text': 'производительности'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,сов,пе=непрош,ед,изъяв,3-л', 'lex': 'потерять'}],
#    'text': 'потеряет'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'ни'}], 'text': 'ни'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,мн', 'lex': 'секунда'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'секунда'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'секунда'}],
#    'text': 'секунды'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'а'}], 'text': 'а'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'полезность'},
#     {'gr': 'S,жен,неод=им,ед', 'lex': 'полезность'}],
#    'text': 'полезность'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'довольно'}], 'text': 'довольно'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'таки'}], 'text': 'таки'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'большой'}],
#    'text': 'большая'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'сколько'}], 'text': 'Сколько'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,сред,неод=вин', 'lex': 'это'},
#     {'gr': 'SPRO,ед,сред,неод=им', 'lex': 'это'}],
#    'text': 'это'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,нп=непрош,ед,изъяв,3-л', 'lex': 'стоять'}],
#    'text': 'стоит'},
#   {'text': '? '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADVPRO=', 'lex': 'как'}], 'text': 'Как'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'уже'}], 'text': 'уже'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,пе=прош,ед,изъяв,муж,несов', 'lex': 'упоминать'}],
#    'text': 'упоминал'},
#   {'text': ' — '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'сервис'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'сервис'}],
#    'text': 'сервис'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'далеко'}], 'text': 'далеко'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'не'}], 'text': 'не'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=ед,кр,муж', 'lex': 'бесплатный'}],
#    'text': 'бесплатен'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'хоть'}], 'text': 'хоть'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,несов,пе=непрош,ед,изъяв,3-л', 'lex': 'иметь'}],
#    'text': 'имеет'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A,полн=вин,ед,жен', 'lex': 'тестовый'}],
#    'text': 'тестовую'},
#   {'text': '-'},
#   {'analysis': [{'gr': 'A=вин,ед,полн,жен', 'lex': 'бесплатный'}],
#    'text': 'бесплатную'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'версия'}],
#    'text': 'версию'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'V=непрош,ед,изъяв,1-л,сов', 'lex': 'рассказывать'}],
#    'text': 'Расскажу'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=срав', 'lex': 'подробно'}], 'text': 'подробнее'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'о'}], 'text': 'о'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,ед', 'lex': 'тарификация'},
#     {'gr': 'S,жен,неод=вин,мн', 'lex': 'тарификация'},
#     {'gr': 'S,жен,неод=дат,ед', 'lex': 'тарификация'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'тарификация'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'тарификация'}],
#    'text': 'тарификации'},
#   {'text': '. '},
#   {'text': '1'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'бесплатный'}],
#    'text': 'Бесплатная'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A,полн=им,ед,жен', 'lex': 'тестовый'}],
#    'text': 'тестовая'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'версия'}],
#    'text': 'версия'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'V,пе=непрош,ед,изъяв,3-л,несов', 'lex': 'включать'}],
#    'text': 'Включает'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO=вин', 'lex': 'себя'},
#     {'gr': 'SPRO=род', 'lex': 'себя'}],
#    'text': 'себя'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'возможность'},
#     {'gr': 'S,жен,неод=им,ед', 'lex': 'возможность'}],
#    'text': 'возможность'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,мн', 'lex': 'отслеживание'},
#     {'gr': 'S,сред,неод=род,ед', 'lex': 'отслеживание'},
#     {'gr': 'S,сред,неод=им,мн', 'lex': 'отслеживание'}],
#    'text': 'отслеживания'},
#   {'text': ' '},
#   {'text': '5'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=род,мн', 'lex': 'посещение'}],
#    'text': 'посещений'},
#   {'text': ', '},
#   {'text': '4'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,мн', 'lex': 'страница'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'страница'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'страница'}],
#    'text': 'страницы'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=пр,ед', 'lex': 'сайт'}], 'text': 'сайте'},
#   {'text': '. '},
#   {'text': '2'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'A=им,ед,полн,жен', 'lex': 'базовый'}],
#    'text': 'Базовая'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'версия'}],
#    'text': 'версия'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=пр,ед,жен', 'lex': 'этот'},
#     {'gr': 'APRO=дат,ед,жен', 'lex': 'этот'},
#     {'gr': 'APRO=род,ед,жен', 'lex': 'этот'},
#     {'gr': 'APRO=твор,ед,жен', 'lex': 'этот'}],
#    'text': 'этой'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,ед', 'lex': 'версия'},
#     {'gr': 'S,жен,неод=вин,мн', 'lex': 'версия'},
#     {'gr': 'S,жен,неод=дат,ед', 'lex': 'версия'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'версия'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'версия'}],
#    'text': 'версии'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV,прдк=', 'lex': 'можно'}], 'text': 'можно'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V=инф,сов', 'lex': 'отслеживать'}],
#    'text': 'отследить'},
#   {'text': ' '},
#   {'text': '10'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=род,мн', 'lex': 'посещение'}],
#    'text': 'посещений'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'text': '10'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=род,мн', 'lex': 'страница'}],
#    'text': 'страниц'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'что'}], 'text': 'что'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'вполне'}], 'text': 'вполне'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'достаточно'}], 'text': 'достаточно'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,од', 'lex': 'средний'},
#     {'gr': 'A=род,ед,полн,муж', 'lex': 'средний'},
#     {'gr': 'A=род,ед,полн,сред', 'lex': 'средний'}],
#    'text': 'среднего'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,од', 'lex': 'корпоративный'},
#     {'gr': 'A=род,ед,полн,муж', 'lex': 'корпоративный'},
#     {'gr': 'A=род,ед,полн,сред', 'lex': 'корпоративный'}],
#    'text': 'корпоративного'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'сайт'}], 'text': 'сайта'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'V,несов,нп=непрош,ед,изъяв,3-л', 'lex': 'стоять'}],
#    'text': 'Стоит'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,неод', 'lex': 'базовый'},
#     {'gr': 'A=им,ед,полн,муж', 'lex': 'базовый'}],
#    'text': 'базовый'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'комплект'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'комплект'}],
#    'text': 'комплект'},
#   {'text': ' — '},
#   {'text': '9'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,мн', 'lex': 'доллар'}],
#    'text': 'долларов'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'месяц'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'месяц'}],
#    'text': 'месяц'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=вин,ед,муж,неод', 'lex': 'этот'},
#     {'gr': 'APRO=им,ед,муж', 'lex': 'этот'}],
#    'text': 'этот'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'комплект'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'комплект'}],
#    'text': 'комплект'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,пе=прош,мн,прич,кр,сов,страд', 'lex': 'включать'}],
#    'text': 'включены'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=им,мн', 'lex': 'весь'},
#     {'gr': 'APRO=вин,ед,сред', 'lex': 'весь'},
#     {'gr': 'APRO=им,ед,сред', 'lex': 'весь'},
#     {'gr': 'APRO=вин,мн,неод', 'lex': 'весь'}],
#    'text': 'все'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,мн,полн,неод', 'lex': 'дополнительный'},
#     {'gr': 'A=им,мн,полн', 'lex': 'дополнительный'}],
#    'text': 'дополнительные'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,ед', 'lex': 'функция'},
#     {'gr': 'S,жен,неод=вин,мн', 'lex': 'функция'},
#     {'gr': 'S,жен,неод=дат,ед', 'lex': 'функция'},
#     {'gr': 'S,жен,неод=род,ед', 'lex': 'функция'},
#     {'gr': 'S,жен,неод=им,мн', 'lex': 'функция'}],
#    'text': 'функции'},
#   {'text': '. '},
#   {'text': '3'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'версия'}],
#    'text': 'Версия'},
#   {'text': ' «'},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'стандарт'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'стандарт'}],
#    'text': 'Стандарт'},
#   {'text': '»'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'В'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,3-л,жен=вин', 'lex': 'она'},
#     {'gr': 'SPRO,ед,3-л,жен=род', 'lex': 'она'}],
#    'text': 'неё'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л,несов', 'lex': 'входить'}],
#    'text': 'входит'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=вин,ед', 'lex': 'возможность'},
#     {'gr': 'S,жен,неод=им,ед', 'lex': 'возможность'}],
#    'text': 'возможность'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,мн', 'lex': 'отслеживание'},
#     {'gr': 'S,сред,неод=род,ед', 'lex': 'отслеживание'},
#     {'gr': 'S,сред,неод=им,мн', 'lex': 'отслеживание'}],
#    'text': 'отслеживания'},
#   {'text': ' '},
#   {'text': '25'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=род,мн', 'lex': 'посещение'}],
#    'text': 'посещений'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'на'}], 'text': 'на'},
#   {'text': ' '},
#   {'text': '20'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=пр,мн', 'lex': 'страница'}],
#    'text': 'страницах'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'вполне'}], 'text': 'Вполне'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л,несов', 'lex': 'подходить'}],
#    'text': 'подходит'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,мн', 'lex': 'тестирование'},
#     {'gr': 'S,сред,неод=род,ед', 'lex': 'тестирование'},
#     {'gr': 'S,сред,неод=им,мн', 'lex': 'тестирование'}],
#    'text': 'тестирования'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,од', 'lex': 'новый'},
#     {'gr': 'A=род,ед,полн,муж', 'lex': 'новый'},
#     {'gr': 'A=род,ед,полн,сред', 'lex': 'новый'}],
#    'text': 'нового'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,ед',
#      'lex': 'стартап',
#      'qual': 'bastard'}],
#    'text': 'стартапа'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'V,несов=непрош,ед,изъяв,3-л', 'lex': 'стоить'}],
#    'text': 'Стоит'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,3-л,жен=им', 'lex': 'она'}], 'text': 'она'},
#   {'text': ' '},
#   {'text': '19'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,мн', 'lex': 'доллар'}],
#    'text': 'долларов'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'в'}], 'text': 'в'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'месяц'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'месяц'}],
#    'text': 'месяц'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'PART=', 'lex': 'именно'}], 'text': 'именно'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,3-л,жен=вин', 'lex': 'она'},
#     {'gr': 'SPRO,ед,3-л,жен=род', 'lex': 'она'}],
#    'text': 'её'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'SPRO,ед,1-л=им', 'lex': 'я'}], 'text': 'я'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'V,сов,пе=прош,ед,изъяв,муж', 'lex': 'купить'}],
#    'text': 'купил'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,мн', 'lex': 'тестирование'},
#     {'gr': 'S,сред,неод=род,ед', 'lex': 'тестирование'},
#     {'gr': 'S,сред,неод=им,мн', 'lex': 'тестирование'}],
#    'text': 'тестирования'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'сервис'}],
#    'text': 'сервиса'},
#   {'text': ', '},
#   {'analysis': [{'gr': 'CONJ=', 'lex': 'и'}], 'text': 'и'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,мн', 'lex': 'написание'},
#     {'gr': 'S,сред,неод=род,ед', 'lex': 'написание'},
#     {'gr': 'S,сред,неод=им,мн', 'lex': 'написание'}],
#    'text': 'написания'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'APRO=вин,ед,муж,од', 'lex': 'этот'},
#     {'gr': 'APRO=род,ед,муж', 'lex': 'этот'},
#     {'gr': 'APRO=род,ед,сред', 'lex': 'этот'}],
#    'text': 'этого'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,ед', 'lex': 'обзор'}],
#    'text': 'обзора'},
#   {'text': '. '},
#   {'text': '4'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'S,жен,неод=им,ед', 'lex': 'версия'}],
#    'text': 'Версия'},
#   {'text': ' «'},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'плюс'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'плюс'}],
#    'text': 'Плюс'},
#   {'text': '»'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'V,нп=непрош,ед,изъяв,3-л,несов', 'lex': 'отличаться'}],
#    'text': 'Отличается'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'от'}], 'text': 'от'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=пр,ед,полн,жен', 'lex': 'предыдущий'},
#     {'gr': 'A=дат,ед,полн,жен', 'lex': 'предыдущий'},
#     {'gr': 'A=род,ед,полн,жен', 'lex': 'предыдущий'},
#     {'gr': 'A=твор,ед,полн,жен', 'lex': 'предыдущий'},
#     {'gr': 'A=срав', 'lex': 'предыдущий'}],
#    'text': 'предыдущей'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=твор,ед', 'lex': 'возможность'}],
#    'text': 'возможностью'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=вин,мн', 'lex': 'отслеживание'},
#     {'gr': 'S,сред,неод=род,ед', 'lex': 'отслеживание'},
#     {'gr': 'S,сред,неод=им,мн', 'lex': 'отслеживание'}],
#    'text': 'отслеживания'},
#   {'text': ' '},
#   {'text': '100'},
#   {'text': ' '},
#   {'text': '000'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,сред,неод=род,мн', 'lex': 'посещение'}],
#    'text': 'посещений'},
#   {'text': ', '},
#   {'text': '50'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,жен,неод=род,мн', 'lex': 'страница'}],
#    'text': 'страниц'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'ADV=', 'lex': 'очень'}], 'text': 'Очень'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=вин,ед,полн,муж,неод', 'lex': 'хороший'},
#     {'gr': 'A=им,ед,полн,муж', 'lex': 'хороший'}],
#    'text': 'хороший'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=вин,ед', 'lex': 'тариф'},
#     {'gr': 'S,муж,неод=им,ед', 'lex': 'тариф'}],
#    'text': 'тариф'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'PR=', 'lex': 'для'}], 'text': 'для'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'A=пр,мн,полн', 'lex': 'крупный'},
#     {'gr': 'A=вин,мн,полн,од', 'lex': 'крупный'},
#     {'gr': 'A=род,мн,полн', 'lex': 'крупный'}],
#    'text': 'крупных'},
#   {'text': ' '},
#   {'analysis': [{'gr': 'S,муж,неод=род,мн', 'lex': 'сервис'}],
#    'text': 'сервисов'},
#   {'text': '. '},
#   {'text': '\\s'},
#   {'analysis': [{'gr': 'V,несов,нп=непрош,ед,изъяв,3-л', 'lex': 'стоять'}],
#    'text': 'Стоит'},
#   {'text': ' '},
#   {'text': '49'},
#   ...]]

# %%
words = []
lemmas1 = []
lemmas2 = []
context = []
sent = ''
for i, parse in enumerate(t):
    for j, word in enumerate(parse):
        if 'analysis' in word.keys() and word['analysis']:
            if word['analysis'][0]['lex']!=disambig[i][j]['analysis'][0]['lex']: 
                words.append(word['text'])
                lemmas1.append(word['analysis'][0]['lex'])
                lemmas2.append(disambig[i][j]['analysis'][0]['lex'])
                # да, первый контекст оказался без первого слова, но смысла это не меняет :С
                while disambig[i][j]['text'] != '\\s' and j>0:
                    j-=1
                k = 1
                while disambig[i][j+k]['text'] != '\\s':
                    sent += disambig[i][j+k]['text']
                    k+=1
                context.append(sent)     
                sent = ''

# %%
disambig_df = pandas.DataFrame([words, lemmas1, lemmas2, context] ).T
disambig_df.columns = ['word','mystem','disambiguation','context']
disambig_df
# Out:
#           word      mystem disambiguation  \
# 0        будет       будет           быть
# 1    говорящим    говорить      говорящий
# 2         выше      высоко           выше
# 3         тому          то            тот
# 4          тем          то            тем
# 5       теплее      теплый          тепло
# 6          тем          то            тем
# 7       больше      больше          много
# 8          тем          то            тем
# 9   Разумеется  разуметься     разумеется
# 10          им          он            они
# 11       может        мочь          может
# 12        есть        быть           есть
# 13       этого         это           этот
# 14      больше      больше          много
# 15       будет       будет           быть
# 16       будет       будет           быть
# 17    стартапа    стартапа        стартап
# 18       Стоит      стоять         стоить
# 19       этого         это           этот
# 20       этого         это           этот
# 21       нужно       нужно         нужный
# 22        этом         это           этот
# 23   прошедшим   прошедшее      прошедший
# 24       всего         все           весь
#
#                                               context
# 0    заметка будет о сервисе отслеживания активнос...
# 1   Я не знаю кому обязан сервис таким говорящим и...
# 2   Как уже сказано выше это сервис для отслеживан...
# 3   Как уже сказано выше это сервис для отслеживан...
# 4   Сервис позволяет отслеживать активность опреде...
# 5   Сервис позволяет отслеживать активность опреде...
# 6   Сервис позволяет отслеживать активность опреде...
# 7   Сервис позволяет отслеживать активность опреде...
# 8   Сервис позволяет отслеживать активность опреде...
# 9   Разумеется сервис изначально планировался как ...
# 10  Разумеется сервис изначально планировался как ...
# 11  Разумеется сервис изначально планировался как ...
# 12  Точнее бесплатная возможность потестировать ес...
# 13  С помощью этого сервиса можно тасовать блоки н...
# 14  С помощью этого сервиса можно тасовать блоки н...
# 15  Ведь альтруизм это хорошо, а деньги на содержа...
# 16  Ведь альтруизм это хорошо, а деньги на содержа...
# 17  Вполне подходит для тестирования нового старта...
# 18  Стоит она 19 долларов в месяц, именно её я куп...
# 19  Стоит она 19 долларов в месяц, именно её я куп...
# 20  Рекомендую, т.к. сам пользуюсь им для этого бл...
# 21  Использовать сервис нужно для тестирования рек...
# 22  К счастью для людей, которые поиздержались ден...
# 23                 PS: Всех с прошедшим Новым годом!
# 24  От всей души желаю вам всего самого-самого луч...

# %% [markdown]
# Я подумала, что анализ разборов -- это, конечно, хорошо, но стоит учитывать, что как правило при лемматизации/любой другой операции со словами берется только первый (наиболее вероятный) вариант, поэтому именно такие варианты я и сравнивала. Я взяла самые первые леммы в разборе слов и выделила только те, что отличаются, а также выделила контекст.
# Что хорошего произошло с дизамбигуацией?<br/>
# 1) Местами починилась правильная лемматизация:<br/>
# **им - он - они**	<br/>
# **этом - это - этот**	<br/>
# **тому	- то - тот**<br/>
# 2) Правильно выделились релевантные начальные формы глаголов:<br/>
# **Стоит	- стоять - стоить**	<br/>
# Для всех остальных слов, пусть это и не влияет на выдачу, существенно уменьшилось число разборов, причем остались, как мне кажется, более релевантные. Отсюда вывод -- дизамбигуация в mystem повышает точность разбора слов в предложении.
